# %%
import pandas as pd
import numpy as np
import nltk
import pyspark
import matplotlib.pyplot as plt
import os.path as osp
import os
import shutil

# %matplotlib notebook

# %%
CWD = '/home/matt/etl'
os.chdir(CWD)
# !ls
# Out:
# open-secrets  open-secrets.ipynb

# %% [markdown]
# Move all the data into the "open-secrets" folder

# %%
# !mkdir -p open-secrets/CampaignFin18
# !mv CampaignFin18.zip open-secrets/CampaignFin18
os.chdir('open-secrets/CampaignFin18')

# %%
# !unzip CampaignFin18.zip

# %%
# !cat CF_2018_Read_Me.txt
# Out:
# Record Count - 7/13/18
#
# Candidates
# ----------
# 7237
#
# Committees
# ----------
# 18100
#
# PACs
# ----
# 191318
#
# Pac_Other
# ---------
# 106795
#
# Individual
# ----------
# 10677360

# %% [markdown]
# # `cands18`: data processing example

# %%
import pyspark
from pyspark.sql.types import StringType, IntegerType, StructType, StructField, FloatType, BooleanType, DateType

# %% [markdown]
# `cands18` schema string: https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20Candidates%20Data.htm

# %%
cands18SchemaStr = [
'''Cycle
Last year (even year) of the federal two year election cycle
Text (4)
FEC''',

'''FECCandID
Assigned by FEC and selected by CRP as the active, should multiples exist.
Text (9)
FEC''',

'''CID
Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID.
Text (9)
CRP''',

'''FirstLastP
Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D)
Text (50)
CRP''',

'''Party
The party of the candidate. "D" for Democratic, "R" for Republican", "I" for Independent, "L" for Libertarian", "3" for other third party and "U" for Unknown.
Text (1)
CRP''',

'''DistIDRunFor
Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and "S1" or "S2" for Senate candidates. "PRES" indicates a presidential candidate.
Text (4)
CRP''',

'''DistIDCurr
Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are "S1" or "S2". "PRES" indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle.
Text (4)
CRP''',

'''CurrCand
This field indicates whether the candidate is currently running for federal office - "Y" means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election.
Text (1)
CRP''',

'''CycleCand
This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, "Y" means yes and blank means no. This field should be "Y" for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that we've tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a "Y" in CycleCand unless there is evidence to the contrary.
Text (1)
CRP''',

'''CRPICO
Identifies type of candidate - "I" is incumbent, "C" is challenger, "O" is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of "C" or "O", not "I."
Text (1)
CRP''',

'''RecipCode
A two-character code defining the type of candidate. The first character is party ("D" for Democratic, "R" for Republican, "3" for Independent or third party, "U" for Unknown.) The second character is "W" for Winner, "L" for Loser, "I" for incumbent, "C" for Challenger, "O" for "Open Seat", and "N" for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. "N" is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP.
Text (2)
CRP''',

'''NoPacs
Indicates whether candidate has publicly committed to forego contributions from PACs
Text (1)
CRP'''
]

# %% [markdown]
# Define helper class `Schema`

# %%
import time
import datetime

# %%
def now():
    return datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d %H:%M:%S.%f')

# %%
class Schema(object):
    
    @classmethod
    def __init__(self, schema_str):
        self.column_names = None
        self._initialized = False
        self._column_dt_formats = {}
        
        self._schema_str = schema_str
        self.process_schema()
    
    @classmethod
    def _check_init(self):
        if not self._initialized:
            raise Exception('Schema not initialized')
    
    @staticmethod
    def spark_dtype(col_info):
        dtype = col_info
        if hasattr(col_info, '__get__'):
            dtype = col_info['dataType']

        if Schema._is_text_datatype(dtype):
            return StringType()
        elif Schema._is_integer_datatype(dtype):
            return IntegerType()
        elif Schema._is_float_datatype(dtype):
            return FloatType()
        elif Schema._is_bool_datatype(dtype):
            return BooleanType()
        elif Schema._is_datetime_datatype(dtype):
            return DateType()
        else:
            raise Exception(f'Unknown datatype: {dtype}')
    
    @staticmethod
    def pandas_dtype(col_info):
        dtype = col_info
        if hasattr(col_info, '__get__'):
            dtype = col_info['dataType']

        if Schema._is_text_datatype(dtype):
            return 'str'
        elif Schema._is_integer_datatype(dtype):
            return 'int'
        elif Schema._is_float_datatype(dtype):
            return 'float'
        elif Schema._is_bool_datatype(dtype):
            return 'bool'
        elif Schema._is_datetime_datatype(dtype):
            return 'str'  # Pandas doesn't care about datetimes in the schema string, you have to tell it about them separately.
        else:
            raise Exception(f'Unknown datatype: {dtype}')
            
    @staticmethod
    def hive_dtype(col_info):
        dtype = col_info
        if hasattr(col_info, '__get__'):
            dtype = col_info['dataType']

        if Schema._is_text_datatype(dtype):
            return 'STRING'
        elif Schema._is_integer_datatype(dtype):
            return 'INTEGER'
        elif Schema._is_float_datatype(dtype):
            return 'DOUBLE'
        elif Schema._is_bool_datatype(dtype):
            return 'BOOLEAN'
        elif Schema._is_datetime_datatype(dtype):
            return 'DATE'
        else:
            raise Exception(f'Unknown datatype: {dtype}')
    
    @classmethod
    def process_schema(self):
        if self._initialized:
            raise Exception('Schema already initialized')
        
        self.parsed_schema = [{
            'name': self.add_name(name),
            'description': description,
            'dataType': dataType,
            'source': source,
            'sparkDtype': Schema.spark_dtype(dataType),
            'pandasDtype': Schema.pandas_dtype(dataType),
            'hiveDtype': Schema.hive_dtype(dataType)
        } for (name, description, dataType, source) in map(lambda c: c.split('\n'), self._schema_str)]
        
        self._initialized = True
    
    @classmethod
    def add_name(self, col_name):
        if self.column_names is None:
            self.column_names = [col_name]
        else:
            self.column_names.append(col_name)
        return col_name
    
    @classmethod
    def register_column_datetime_formats(self, formats):
        if formats:
            for col, fmt in formats.items():
                self._column_dt_formats[col] = fmt
        
    @classmethod
    def get_pandas_schema(self):
        self._check_init()
        return { col['name']: col['pandasDtype'] for col in self.parsed_schema }
    
    @classmethod
    def get_spark_dtypes(self):
        self._check_init()
        return StructType([ StructField(col['name'], col['sparkDtype'], True) for col in self.parsed_schema ])
    
    @classmethod
    def get_dt_colnames(self):
        self._check_init()
        return list(filter(lambda c: Schema._is_datetime_datatype(c['dataType']), self.parsed_schema))
    
    @classmethod
    def hive_ddl(self, tableName, externalTableLocation, external=True):
        self._check_init()
        columnData = []
        for c in self.parsed_schema:
            columnStr = "`{}` {} COMMENT '{}, orig-datatype {}, source {}'".format(c['name'],
                                                                                 c['hiveDtype'],
                                                                                 c['description'].replace("'", "").replace('"', ''),
                                                                                 c['dataType'].replace("'", "").replace('"', ''),
                                                                                 c['source'].replace("'", "").replace('"', ''))
            columnData.append(columnStr)
        
        ddl = """
DROP TABLE {tableName};
        
CREATE{isExternal} TABLE {tableName}
(
    {columnPart}
)
COMMENT 'Auto-generated schema at {now} from {externalTableLocation}'
ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
WITH SERDEPROPERTIES (
   "separatorChar" = ",",
   "quoteChar"     = "|"
)
STORED AS TEXTFILE
LOCATION '{externalTableLocation}';

""".format(isExternal=' EXTERNAL' if external else '',
           tableName=tableName,
           columnPart=',\n    '.join(columnData),
           now=now(),
           externalTableLocation=externalTableLocation)
        return ddl
    
    @classmethod
    def hive_ddl_parquet(self, tableName, originalTableName):
        """
        Create a new table by selecting data out of an existing (external) table and inserting
        into a parquet table managed by Hive.
        """
        self._check_init()
        selectData = []
        alterTableStmtsList = []
        for c in self.parsed_schema:
            dtype = c['hiveDtype']
            if dtype == 'STRING':
                columnStr = "`{name}` AS `{name}`".format(name=c['name'])
            elif dtype == 'INTEGER':
                columnStr = "CAST(`{name}` AS {dtype}) AS `{name}`".format(name=c['name'], dtype=dtype)
            elif dtype == 'DOUBLE':
                columnStr = "CAST(`{name}` AS {dtype}) AS `{name}`".format(name=c['name'], dtype=dtype)
            elif dtype == 'BOOLEAN':
                columnStr = "CAST(`{name}` AS {dtype}) AS `{name}`".format(name=c['name'], dtype=dtype)
            elif dtype == 'DATE':
                columnStr = "TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`{name}`, '{dtConvStr}'))) AS `{name}`".format(name=c['name'],
                                                                                            dtConvStr=self._column_dt_formats[c['name']])
            
            comment = c['description'].replace("'", "").replace('"', '')
            alterTableStmt = "ALTER TABLE {tableName} CHANGE `{name}` `{name}` {dtype} COMMENT '{comment}';".format(tableName=tableName,
                                                                                                                    name=c['name'],
                                                                                                                    dtype=dtype,
                                                                                                                    comment=comment)
            
            selectData.append(columnStr)
            alterTableStmtsList.append(alterTableStmt)
            
        ddl = """
DROP TABLE {tableName};
        
CREATE TABLE {tableName} 
COMMENT 'Auto-generated schema at {now} from {originalTableName}' 
STORED AS PARQUET 
AS SELECT
    {selectStatement}
FROM {originalTableName};

{alterTableStmts}
""".format(tableName=tableName,
           originalTableName=originalTableName,
           selectStatement=',\n    '.join(selectData),
           now=now(),
           alterTableStmts='\n'.join(alterTableStmtsList)
           )
        return ddl
    
    
    @staticmethod
    def _is_text_datatype(dtype):
        return dtype.lower().startswith('text')
    
    @staticmethod
    def _is_integer_datatype(dtype):
        return dtype.lower().startswith('integer')

    @staticmethod
    def _is_float_datatype(dtype):
        if 'precision' in dtype.lower():
            return True
        elif 'float' in dtype.lower():
            return True
        return False

    @staticmethod
    def _is_bool_datatype(dtype):
        return dtype.lower().startswith('bit')

    @staticmethod
    def _is_datetime_datatype(dtype):
        if 'mm/dd/yyyy' in dtype.lower():
            return True
        elif 'date' in dtype.lower():
            return True
        return False

# %%
cands18Schema = Schema(cands18SchemaStr)
cands18 = pd.read_csv('cands18.txt', quotechar='|', delimiter=',', 
                      parse_dates=cands18Schema.get_dt_colnames(), infer_datetime_format=True,
                      header=None, dtype=cands18Schema.get_pandas_schema(), names=cands18Schema.column_names)

cands18.head(3)
# Out:
#   Cycle  FECCandID        CID           FirstLastP Party DistIDRunFor  \
# 0  2018  H6FL08221  N00028542        D J Mauro (I)     I         FL08
# 1  2018  H6NC09200  N00035491      Mark Harris (R)     R         NC09
# 2  2018  H4NE01163  N00035619  Dennis Crawford (D)     D         NE01
#
#   DistIDCurr CurrCand CycleCand CRPICO RecipCode NoPacs
# 0                                             3N
# 1                                    O        RO
# 2                             Y      C        DL

# %% [markdown]
# Put it in Hive

# %%
# !hdfs dfs -mkdir -p /staging/cands18
# !hdfs dfs -put cands18.txt /staging/cands18/cands18.txt
# Out:
# 2018-10-07 14:38:38,961 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 14:38:40,886 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
with open('cands18.sql', 'w') as f:
    f.write(cands18Schema.hive_ddl(tableName='cands18', externalTableLocation='/staging/cands18/'))

# %%
# !/opt/hive/bin/beeline -u jdbc:hive2://cap1:10000 -n matt -p anything -f cands18.sql
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE cands18;
# INFO  : Compiling command(queryId=hadoop_20181007144738_80b45164-a632-45c3-a780-a2451c8038d1): DROP TABLE cands18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007144738_80b45164-a632-45c3-a780-a2451c8038d1); Time taken: 0.011 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007144738_80b45164-a632-45c3-a780-a2451c8038d1): DROP TABLE cands18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007144738_80b45164-a632-45c3-a780-a2451c8038d1); Time taken: 0.052 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.128 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE cands18
# . . . . . . . . . . . . . > (
# he federal two year election cycle, orig-datatype Text (4), source FEC',
# urce FEC',
# . Recipid for candidates is based on CID., orig-datatype Text (9), source CRP',
# pe Text (50), source CRP',
# r other third party and U for Unknown., orig-datatype Text (1), source CRP',
# ., orig-datatype Text (4), source CRP',
# pe Text (4), source CRP',
# n., orig-datatype Text (1), source CRP',
# to the contrary., orig-datatype Text (1), source CRP',
#  CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# ), source CRP',
# (1), source CRP'
# . . . . . . . . . . . . . > )
# 1.230978 from /staging/cands18/'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/cands18/';
# INFO  : Compiling command(queryId=hadoop_20181007144738_affd5bb7-327d-48ea-9585-a4a4ad455a9d): CREATE EXTERNAL TABLE cands18
# (
# Cycle STRING COMMENT 'Last year (even year) of the federal two year election cycle, orig-datatype Text (4), source FEC',
# FECCandID STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist., orig-datatype Text (9), source FEC',
# CID STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID., orig-datatype Text (9), source CRP',
# FirstLastP STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D), orig-datatype Text (50), source CRP',
# Party STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown., orig-datatype Text (1), source CRP',
# DistIDRunFor STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate., orig-datatype Text (4), source CRP',
# DistIDCurr STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle., orig-datatype Text (4), source CRP',
# CurrCand STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election., orig-datatype Text (1), source CRP',
# CycleCand STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary., orig-datatype Text (1), source CRP',
# CRPICO STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# RecipCode STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP., orig-datatype Text (2), source CRP',
# NoPacs STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs, orig-datatype Text (1), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 14:43:11.230978 from /staging/cands18/'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cands18/'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007144738_affd5bb7-327d-48ea-9585-a4a4ad455a9d); Time taken: 0.006 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007144738_affd5bb7-327d-48ea-9585-a4a4ad455a9d): CREATE EXTERNAL TABLE cands18
# (
# Cycle STRING COMMENT 'Last year (even year) of the federal two year election cycle, orig-datatype Text (4), source FEC',
# FECCandID STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist., orig-datatype Text (9), source FEC',
# CID STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID., orig-datatype Text (9), source CRP',
# FirstLastP STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D), orig-datatype Text (50), source CRP',
# Party STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown., orig-datatype Text (1), source CRP',
# DistIDRunFor STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate., orig-datatype Text (4), source CRP',
# DistIDCurr STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle., orig-datatype Text (4), source CRP',
# CurrCand STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election., orig-datatype Text (1), source CRP',
# CycleCand STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary., orig-datatype Text (1), source CRP',
# CRPICO STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# RecipCode STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP., orig-datatype Text (2), source CRP',
# NoPacs STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs, orig-datatype Text (1), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 14:43:11.230978 from /staging/cands18/'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cands18/'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007144738_affd5bb7-327d-48ea-9585-a4a4ad455a9d); Time taken: 0.025 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.042 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000

# %% [markdown]
# >

# %% [markdown]
# Verify that we can read the table

# %%
sc = pyspark.sql.SparkSession.Builder()\
        .master('yarn')\
        .appName('open-secrets-etl')\
        .enableHiveSupport()\
        .getOrCreate()

# %% [markdown]
# Write back to Hive warehouse as parquet format:

# %%
df = sc.sql('SELECT * FROM cands18')

# %%
df.write.saveAsTable(name='pqcands18', format='parquet', mode='overwrite')

# %%
# !hdfs dfs -ls /user/hive/warehouse
# Out:
# 2018-10-07 14:51:35,017 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Found 1 items
# drwxr-xr-x   - matt supergroup          0 2018-10-07 14:51 /user/hive/warehouse/pqcands18

# %% [markdown]
# How much faster is it than reading CSVs from Hive?

# %%
# %timeit sc.sql('SELECT COUNT(*) FROM cands18')
# Out:
# 16.7 ms ± 2.37 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit sc.sql('SELECT COUNT(*) FROM pqcands18')
# Out:
# 10.7 ms ± 705 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# About 50% speedup! Now we just need to clean up

# %%
sc.sql('DESCRIBE TABLE pqcands18').collect()
# Out:
# [Row(col_name='cycle', data_type='string', comment='from deserializer'),
#  Row(col_name='feccandid', data_type='string', comment='from deserializer'),
#  Row(col_name='cid', data_type='string', comment='from deserializer'),
#  Row(col_name='firstlastp', data_type='string', comment='from deserializer'),
#  Row(col_name='party', data_type='string', comment='from deserializer'),
#  Row(col_name='distidrunfor', data_type='string', comment='from deserializer'),
#  Row(col_name='distidcurr', data_type='string', comment='from deserializer'),
#  Row(col_name='currcand', data_type='string', comment='from deserializer'),
#  Row(col_name='cyclecand', data_type='string', comment='from deserializer'),
#  Row(col_name='crpico', data_type='string', comment='from deserializer'),
#  Row(col_name='recipcode', data_type='string', comment='from deserializer'),
#  Row(col_name='nopacs', data_type='string', comment='from deserializer')]

# %% [markdown]
# Well, we lost our comments, but they are still with us in our hearts. And in the `.sql` file. Internet doesn't show any easy ways of preserving them so we won't worry about this, although we could add them back with an `ALTER TABLE` statment or two. Now for clean up:

# %%
sc.sql('DROP TABLE cands18')
# !hdfs dfs -rm -r -f /staging/cands18
#!rm -f cands18.txt
# Out:
# 2018-10-07 14:57:15,745 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/cands18

# %% [markdown]
# Verify that the table is deleted and that Hive no longer tracks metadata

# %%
# !/opt/hive/bin/beeline -u jdbc:hive2://cap1:10000 -n matt -p anything -e 'show tables;'
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hadoop_20181007145744_c18ef251-59dd-4ce9-89a9-801e42ce216b): show tables
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007145744_c18ef251-59dd-4ce9-89a9-801e42ce216b); Time taken: 0.009 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007145744_c18ef251-59dd-4ce9-89a9-801e42ce216b): show tables
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007145744_c18ef251-59dd-4ce9-89a9-801e42ce216b); Time taken: 0.028 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +------------+
# |  tab_name  |
# +------------+
# | pqcands18  |
# +------------+
# 1 row selected (0.136 seconds)
# Beeline version 3.1.0 by Apache Hive
# Closing: 0: jdbc:hive2://cap1:10000

# %% [markdown]
# Now we need to turn this into a repeatable, hands-off process

# %% [markdown]
# # Standardized hands-off ETL function

# %%
def etl_text_file(text_file_path, schema_str, table_name, data_source_name, column_datetime_formats=None):
    schema = Schema(schema_str)
    schema.register_column_datetime_formats(column_datetime_formats)
    textFileName = osp.split(text_file_path)[1]
    stagingFolder = f'/staging/{table_name}'
    # !hdfs dfs -mkdir -p {stagingFolder}
    # !hdfs dfs -put {text_file_path} {stagingFolder}/{textFileName}
    with open(f'{table_name}.sql', 'w') as f:
        f.write(schema.hive_ddl(tableName=table_name, externalTableLocation=stagingFolder))
    # !/opt/hive/bin/beeline -u jdbc:hive2://cap1:10000 -n matt -p anything -f {table_name}.sql
    
    # Convert to the proper schema and write as parquet
    finalTableName = f'pq_{data_source_name}_{table_name}'
    with open(f'{finalTableName}.sql', 'w') as f:
        f.write(schema.hive_ddl_parquet(tableName=finalTableName, originalTableName=table_name))
    # !/opt/hive/bin/beeline -u jdbc:hive2://cap1:10000 -n matt -p anything -f {finalTableName}.sql
    
    # clean up -- drop the intermediate (text file) table and delete staged data from HDFS
    sc.sql(f'DROP TABLE {table_name}')
    # !hdfs dfs -rm -r -f {stagingFolder}
    
    print('done')

# %% [markdown]
# # `cands18`

# %%
etl_text_file('cands18.txt', cands18SchemaStr, 'cands18', 'crp')
# Out:
# 2018-10-07 18:29:32,942 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 18:29:34,932 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE cands18;
# INFO  : Compiling command(queryId=hadoop_20181007182939_ff9b2b40-1b75-478f-bdcb-96ae6bcdbf26): DROP TABLE cands18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007182939_ff9b2b40-1b75-478f-bdcb-96ae6bcdbf26); Time taken: 0.005 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007182939_ff9b2b40-1b75-478f-bdcb-96ae6bcdbf26): DROP TABLE cands18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007182939_ff9b2b40-1b75-478f-bdcb-96ae6bcdbf26); Time taken: 0.011 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.073 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE cands18
# . . . . . . . . . . . . . > (
#  the federal two year election cycle, orig-datatype Text (4), source FEC',
# source FEC',
# ,
# type Text (50), source CRP',
# for other third party and U for Unknown., orig-datatype Text (1), source CRP',
# te., orig-datatype Text (4), source CRP',
# type Text (4), source CRP',
# ion., orig-datatype Text (1), source CRP',
# e to the contrary., orig-datatype Text (1), source CRP',
#  a CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# (2), source CRP',
# t (1), source CRP'
# . . . . . . . . . . . . . > )
# 6.395172 from /staging/cands18'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/cands18';
# INFO  : Compiling command(queryId=hadoop_20181007182940_274abccb-f199-47c2-aeed-44ed344ab809): CREATE EXTERNAL TABLE cands18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal two year election cycle, orig-datatype Text (4), source FEC',
# `FECCandID` STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist., orig-datatype Text (9), source FEC',
# `CID` STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID., orig-datatype Text (9), source CRP',
# `FirstLastP` STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D), orig-datatype Text (50), source CRP',
# `Party` STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown., orig-datatype Text (1), source CRP',
# `DistIDRunFor` STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate., orig-datatype Text (4), source CRP',
# `DistIDCurr` STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle., orig-datatype Text (4), source CRP',
# `CurrCand` STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election., orig-datatype Text (1), source CRP',
# `CycleCand` STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary., orig-datatype Text (1), source CRP',
# `CRPICO` STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP., orig-datatype Text (2), source CRP',
# `NoPacs` STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs, orig-datatype Text (1), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 18:29:36.395172 from /staging/cands18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cands18'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007182940_274abccb-f199-47c2-aeed-44ed344ab809); Time taken: 0.053 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007182940_274abccb-f199-47c2-aeed-44ed344ab809): CREATE EXTERNAL TABLE cands18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal two year election cycle, orig-datatype Text (4), source FEC',
# `FECCandID` STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist., orig-datatype Text (9), source FEC',
# `CID` STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID., orig-datatype Text (9), source CRP',
# `FirstLastP` STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D), orig-datatype Text (50), source CRP',
# `Party` STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown., orig-datatype Text (1), source CRP',
# `DistIDRunFor` STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate., orig-datatype Text (4), source CRP',
# `DistIDCurr` STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle., orig-datatype Text (4), source CRP',
# `CurrCand` STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election., orig-datatype Text (1), source CRP',
# `CycleCand` STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary., orig-datatype Text (1), source CRP',
# `CRPICO` STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I., orig-datatype Text (1), source CRP',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP., orig-datatype Text (2), source CRP',
# `NoPacs` STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs, orig-datatype Text (1), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 18:29:36.395172 from /staging/cands18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cands18'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007182940_274abccb-f199-47c2-aeed-44ed344ab809); Time taken: 0.058 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.126 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pq_crp_cands18;
# INFO  : Compiling command(queryId=hadoop_20181007182943_23ae501e-e434-4b73-a815-6046c489cebc): DROP TABLE pq_crp_cands18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007182943_23ae501e-e434-4b73-a815-6046c489cebc); Time taken: 0.003 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007182943_23ae501e-e434-4b73-a815-6046c489cebc): DROP TABLE pq_crp_cands18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007182943_23ae501e-e434-4b73-a815-6046c489cebc); Time taken: 0.012 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.083 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE TABLE pq_crp_cands18
# 0.293305 from cands18'
# . . . . . . . . . . . . . > STORED AS PARQUET
# . . . . . . . . . . . . . > AS SELECT
# . . . . . . . . . . . . . >     `Cycle` AS `Cycle`,
# . . . . . . . . . . . . . >     `FECCandID` AS `FECCandID`,
# . . . . . . . . . . . . . >     `CID` AS `CID`,
# . . . . . . . . . . . . . >     `FirstLastP` AS `FirstLastP`,
# . . . . . . . . . . . . . >     `Party` AS `Party`,
# . . . . . . . . . . . . . >     `DistIDRunFor` AS `DistIDRunFor`,
# . . . . . . . . . . . . . >     `DistIDCurr` AS `DistIDCurr`,
# . . . . . . . . . . . . . >     `CurrCand` AS `CurrCand`,
# . . . . . . . . . . . . . >     `CycleCand` AS `CycleCand`,
# . . . . . . . . . . . . . >     `CRPICO` AS `CRPICO`,
# . . . . . . . . . . . . . >     `RecipCode` AS `RecipCode`,
# . . . . . . . . . . . . . >     `NoPacs` AS `NoPacs`
# . . . . . . . . . . . . . > FROM cands18;
# INFO  : Compiling command(queryId=hadoop_20181007182943_c6f35092-9d0d-4e2d-a2f5-95ef5b0cfb28): CREATE TABLE pq_crp_cands18
# COMMENT 'Auto-generated schema at 2018-10-07 18:29:40.293305 from cands18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECCandID` AS `FECCandID`,
# `CID` AS `CID`,
# `FirstLastP` AS `FirstLastP`,
# `Party` AS `Party`,
# `DistIDRunFor` AS `DistIDRunFor`,
# `DistIDCurr` AS `DistIDCurr`,
# `CurrCand` AS `CurrCand`,
# `CycleCand` AS `CycleCand`,
# `CRPICO` AS `CRPICO`,
# `RecipCode` AS `RecipCode`,
# `NoPacs` AS `NoPacs`
# FROM cands18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:cycle, type:string, comment:null), FieldSchema(name:feccandid, type:string, comment:null), FieldSchema(name:cid, type:string, comment:null), FieldSchema(name:firstlastp, type:string, comment:null), FieldSchema(name:party, type:string, comment:null), FieldSchema(name:distidrunfor, type:string, comment:null), FieldSchema(name:distidcurr, type:string, comment:null), FieldSchema(name:currcand, type:string, comment:null), FieldSchema(name:cyclecand, type:string, comment:null), FieldSchema(name:crpico, type:string, comment:null), FieldSchema(name:recipcode, type:string, comment:null), FieldSchema(name:nopacs, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007182943_c6f35092-9d0d-4e2d-a2f5-95ef5b0cfb28); Time taken: 0.166 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007182943_c6f35092-9d0d-4e2d-a2f5-95ef5b0cfb28): CREATE TABLE pq_crp_cands18
# COMMENT 'Auto-generated schema at 2018-10-07 18:29:40.293305 from cands18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECCandID` AS `FECCandID`,
# `CID` AS `CID`,
# `FirstLastP` AS `FirstLastP`,
# `Party` AS `Party`,
# `DistIDRunFor` AS `DistIDRunFor`,
# `DistIDCurr` AS `DistIDCurr`,
# `CurrCand` AS `CurrCand`,
# `CycleCand` AS `CycleCand`,
# `CRPICO` AS `CRPICO`,
# `RecipCode` AS `RecipCode`,
# `NoPacs` AS `NoPacs`
# FROM cands18
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hadoop_20181007182943_c6f35092-9d0d-4e2d-a2f5-95ef5b0cfb28
# INFO  : Total jobs = 3
# INFO  : Launching Job 1 out of 3
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1538954460508_0002
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://cap1:8088/proxy/application_1538954460508_0002/
# INFO  : Starting Job = job_1538954460508_0002, Tracking URL = http://cap1:8088/proxy/application_1538954460508_0002/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1538954460508_0002
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# INFO  : 2018-10-07 18:29:52,004 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2018-10-07 18:30:00,222 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 4.91 sec
# INFO  : MapReduce Total cumulative CPU time: 4 seconds 910 msec
# INFO  : Ended Job = job_1538954460508_0002
# INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
# INFO  : Stage-4 is selected by condition resolver.
# INFO  : Stage-3 is filtered out by condition resolver.
# INFO  : Stage-5 is filtered out by condition resolver.
# INFO  : Starting task [Stage-4:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-29-43_898_8818401708255074186-3/-ext-10002 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-29-43_898_8818401708255074186-3/-ext-10004
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/pq_crp_cands18 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-29-43_898_8818401708255074186-3/-ext-10002
# INFO  : Starting task [Stage-8:DDL] in serial mode
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1   Cumulative CPU: 4.91 sec   HDFS Read: 677164 HDFS Write: 378970 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 4 seconds 910 msec
# INFO  : Completed executing command(queryId=hadoop_20181007182943_c6f35092-9d0d-4e2d-a2f5-95ef5b0cfb28); Time taken: 17.329 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (17.505 seconds)
# 0: jdbc:hive2://cap1:10000>
# RING COMMENT 'Last year (even year) of the federal two year election cycle';
# INFO  : Compiling command(queryId=hadoop_20181007183001_55bf3f72-2678-4192-b9fe-10bd9acb4c65): ALTER TABLE pq_crp_cands18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal two year election cycle'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_55bf3f72-2678-4192-b9fe-10bd9acb4c65); Time taken: 0.03 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_55bf3f72-2678-4192-b9fe-10bd9acb4c65): ALTER TABLE pq_crp_cands18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal two year election cycle'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_55bf3f72-2678-4192-b9fe-10bd9acb4c65); Time taken: 0.048 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.089 seconds)
# multiples exist.';
# INFO  : Compiling command(queryId=hadoop_20181007183001_10bbe6c5-c6a5-4330-afae-857fb8dbbb67): ALTER TABLE pq_crp_cands18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_10bbe6c5-c6a5-4330-afae-857fb8dbbb67); Time taken: 0.021 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_10bbe6c5-c6a5-4330-afae-857fb8dbbb67): ALTER TABLE pq_crp_cands18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'Assigned by FEC and selected by CRP as the active, should multiples exist.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_10bbe6c5-c6a5-4330-afae-857fb8dbbb67); Time taken: 0.041 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.073 seconds)
# ;
# INFO  : Compiling command(queryId=hadoop_20181007183001_add9b1a0-32e3-40e2-80fa-be75a30514b7): ALTER TABLE pq_crp_cands18 CHANGE `CID` `CID` STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_add9b1a0-32e3-40e2-80fa-be75a30514b7); Time taken: 0.021 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_add9b1a0-32e3-40e2-80fa-be75a30514b7): ALTER TABLE pq_crp_cands18 CHANGE `CID` `CID` STRING COMMENT 'Unique identifier for each candidate. Every candidate should have one and only one CID throughout all cycles. Recipid for candidates is based on CID.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_add9b1a0-32e3-40e2-80fa-be75a30514b7); Time taken: 0.042 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.073 seconds)
#  in parens, like Steve Kagen (D)';
# INFO  : Compiling command(queryId=hadoop_20181007183001_93607626-c56c-4eac-82e3-69b58b99c450): ALTER TABLE pq_crp_cands18 CHANGE `FirstLastP` `FirstLastP` STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D)'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_93607626-c56c-4eac-82e3-69b58b99c450); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_93607626-c56c-4eac-82e3-69b58b99c450): ALTER TABLE pq_crp_cands18 CHANGE `FirstLastP` `FirstLastP` STRING COMMENT 'Candidate name in format of firstname lastname and party in parens, like Steve Kagen (D)'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_93607626-c56c-4eac-82e3-69b58b99c450); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.068 seconds)
# for Independent, L for Libertarian, 3 for other third party and U for Unknown.';
# INFO  : Compiling command(queryId=hadoop_20181007183001_31b266e5-6b95-49bc-b0e4-390f16365629): ALTER TABLE pq_crp_cands18 CHANGE `Party` `Party` STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_31b266e5-6b95-49bc-b0e4-390f16365629); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_31b266e5-6b95-49bc-b0e4-390f16365629): ALTER TABLE pq_crp_cands18 CHANGE `Party` `Party` STRING COMMENT 'The party of the candidate. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_31b266e5-6b95-49bc-b0e4-390f16365629); Time taken: 0.039 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.069 seconds)
# idates. PRES indicates a presidential candidate.';
# INFO  : Compiling command(queryId=hadoop_20181007183001_c5df427c-521b-4994-a8a5-680ad3b69780): ALTER TABLE pq_crp_cands18 CHANGE `DistIDRunFor` `DistIDRunFor` STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_c5df427c-521b-4994-a8a5-680ad3b69780); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_c5df427c-521b-4994-a8a5-680ad3b69780): ALTER TABLE pq_crp_cands18 CHANGE `DistIDRunFor` `DistIDRunFor` STRING COMMENT 'Four character identifier of the office sought by the candidate. For congressional races, the first two characters are the state and the next two are the district for House candidates and S1 or S2 for Senate candidates. PRES indicates a presidential candidate.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_c5df427c-521b-4994-a8a5-680ad3b69780); Time taken: 0.037 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# ld on Election Day of the Cycle.';
# INFO  : Compiling command(queryId=hadoop_20181007183001_5bc2c7bb-bab5-4060-b28e-2210bc2e332a): ALTER TABLE pq_crp_cands18 CHANGE `DistIDCurr` `DistIDCurr` STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_5bc2c7bb-bab5-4060-b28e-2210bc2e332a); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_5bc2c7bb-bab5-4060-b28e-2210bc2e332a): ALTER TABLE pq_crp_cands18 CHANGE `DistIDCurr` `DistIDCurr` STRING COMMENT 'Four character identifier of the office currently held (if any) by the candidate. For House members, the first two characters are the state and the next two are the district. For Senators the first two characters are the state and the last two characters are S1 or S2. PRES indicates a presidential candidate. For non-incumbents, this field is blank. If a member of Congress dies or leaves office, this field should become blank. This field is frozen on election day. For cycles prior to the current cycle, DistidCurr reflects office held on Election Day of the Cycle.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_5bc2c7bb-bab5-4060-b28e-2210bc2e332a); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# he candidate who ran in the general election.';
# INFO  : Compiling command(queryId=hadoop_20181007183001_30db9e53-f659-45b1-ac85-d4778eb9a0f2): ALTER TABLE pq_crp_cands18 CHANGE `CurrCand` `CurrCand` STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183001_30db9e53-f659-45b1-ac85-d4778eb9a0f2); Time taken: 0.021 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183001_30db9e53-f659-45b1-ac85-d4778eb9a0f2): ALTER TABLE pq_crp_cands18 CHANGE `CurrCand` `CurrCand` STRING COMMENT 'This field indicates whether the candidate is currently running for federal office - Y means yes, otherwise this field is blank. If a candidate loses a primary or drops out of the race, this field becomes blank. This field is frozen on Election Day, and thus for previous cycles can be used to show the candidate who ran in the general election.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183001_30db9e53-f659-45b1-ac85-d4778eb9a0f2); Time taken: 0.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.072 seconds)
# t a Y in CycleCand unless there is evidence to the contrary.';
# INFO  : Compiling command(queryId=hadoop_20181007183002_6dd445b8-358b-406f-9b81-7b884e5af43e): ALTER TABLE pq_crp_cands18 CHANGE `CycleCand` `CycleCand` STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183002_6dd445b8-358b-406f-9b81-7b884e5af43e); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183002_6dd445b8-358b-406f-9b81-7b884e5af43e): ALTER TABLE pq_crp_cands18 CHANGE `CycleCand` `CycleCand` STRING COMMENT 'This field indicates whether the candidate ever ran for federal office during the cycle in question. Like CurrCand, Y means yes and blank means no. This field should be Y for any candidate who filed to run for office or otherwise formally declared intention to run. This does NOT change if the candidate drops out or loses a primary. Be aware that weve tightened the definition in recent cycles - for older data, CycleCand is likely to cast a broader net. Also note that incumbents are usually assumed to be running for re-election and get a Y in CycleCand unless there is evidence to the contrary.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183002_6dd445b8-358b-406f-9b81-7b884e5af43e); Time taken: 0.048 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.078 seconds)
# mbent running for the Senate would have a CRPICO of C or O, not I.';
# INFO  : Compiling command(queryId=hadoop_20181007183002_6f218c77-c0d6-4033-ab09-95a6455c1248): ALTER TABLE pq_crp_cands18 CHANGE `CRPICO` `CRPICO` STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183002_6f218c77-c0d6-4033-ab09-95a6455c1248); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183002_6f218c77-c0d6-4033-ab09-95a6455c1248): ALTER TABLE pq_crp_cands18 CHANGE `CRPICO` `CRPICO` STRING COMMENT 'Identifies type of candidate - I is incumbent, C is challenger, O is open seat. This may be blank if the candidate is neither a member of Congress nor running this cycle. Note this is based on the office sought. A House incumbent running for the Senate would have a CRPICO of C or O, not I.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183002_6f218c77-c0d6-4033-ab09-95a6455c1248); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# ives in dbo_CandsCRP.';
# INFO  : Compiling command(queryId=hadoop_20181007183002_81ce7ce9-d6e5-4aba-8ace-a269c6c936ec): ALTER TABLE pq_crp_cands18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183002_81ce7ce9-d6e5-4aba-8ace-a269c6c936ec); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183002_81ce7ce9-d6e5-4aba-8ace-a269c6c936ec): ALTER TABLE pq_crp_cands18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of candidate. The first character is party (D for Democratic, R for Republican, 3 for Independent or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. Incumbent, Challenger and Open Seat are based on CRPICO. N is reserved for candidates that are neither in office nor running during the cycle in question. This lives in dbo_CandsCRP.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183002_81ce7ce9-d6e5-4aba-8ace-a269c6c936ec); Time taken: 0.037 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# tributions from PACs';
# INFO  : Compiling command(queryId=hadoop_20181007183002_3d9dc4a4-2a73-4e38-a6d6-4cdfff318b84): ALTER TABLE pq_crp_cands18 CHANGE `NoPacs` `NoPacs` STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007183002_3d9dc4a4-2a73-4e38-a6d6-4cdfff318b84); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007183002_3d9dc4a4-2a73-4e38-a6d6-4cdfff318b84): ALTER TABLE pq_crp_cands18 CHANGE `NoPacs` `NoPacs` STRING COMMENT 'Indicates whether candidate has publicly committed to forego contributions from PACs'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007183002_3d9dc4a4-2a73-4e38-a6d6-4cdfff318b84); Time taken: 0.037 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.065 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# 2018-10-07 18:30:03,257 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/cands18
# done

# %%
sc.sql('SELECT * FROM pq_crp_cands18').limit(10).show()
# Out:
# +-----+---------+---------+--------------------+-----+------------+----------+--------+---------+------+---------+------+
# |cycle|feccandid|      cid|          firstlastp|party|distidrunfor|distidcurr|currcand|cyclecand|crpico|recipcode|nopacs|
# +-----+---------+---------+--------------------+-----+------------+----------+--------+---------+------+---------+------+
# | 2018|H6FL08221|N00028542|       D J Mauro (I)|    I|        FL08|          |        |         |      |       3N|      |
# | 2018|H6NC09200|N00035491|     Mark Harris (R)|    R|        NC09|          |        |         |     O|       RO|      |
# | 2018|H4NE01163|N00035619| Dennis Crawford (D)|    D|        NE01|          |        |        Y|     C|       DL|      |
# | 2018|H0IN01127|N00041294| Arturas Kerelis (D)|    D|        IN01|          |        |         |      |       DN|      |
# | 2018|H8AL02171|N00041295|     Barry Moore (R)|    R|        AL02|          |        |        Y|     C|       RL|      |
# | 2018|H8AL04078|N00041296|      Mike Moses (R)|    R|        AL04|          |        |        Y|     C|       RN|      |
# | 2018|H8AL04086|N00041297|  Rick Neighbors (D)|    D|        AL04|          |        |        Y|     C|       DL|      |
# | 2018|H8AL05208|N00041298|Clayton Hinchman (R)|    R|        AL05|          |        |        Y|     C|       RL|      |
# | 2018|H8AR02134|N00041299|    Paul Spencer (D)|    D|        AR02|          |        |        Y|     C|       DL|      |
# | 2018|H8AR03074|N00041300|     Josh Mahony (D)|    D|        AR03|          |       Y|        Y|     C|       DC|      |
# +-----+---------+---------+--------------------+-----+------------+----------+--------+---------+------+---------+------+

# %%
sc.sql('DESCRIBE TABLE pq_crp_cands18').show()
# Out:
# +------------+---------+--------------------+
# |    col_name|data_type|             comment|
# +------------+---------+--------------------+
# |       cycle|   string|Last year (even y...|
# |   feccandid|   string|Assigned by FEC a...|
# |         cid|   string|Unique identifier...|
# |  firstlastp|   string|Candidate name in...|
# |       party|   string|The party of the ...|
# |distidrunfor|   string|Four character id...|
# |  distidcurr|   string|Four character id...|
# |    currcand|   string|This field indica...|
# |   cyclecand|   string|This field indica...|
# |      crpico|   string|Identifies type o...|
# |   recipcode|   string|A two-character c...|
# |      nopacs|   string|Indicates whether...|
# +------------+---------+--------------------+

# %% [markdown]
# # `cmtes18`

# %% [markdown]
# `cmtes18` schema string: https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20Candidates%20Data.htm

# %%
cmtes18SchemaStr = [
'''Cycle
Last year (even year) of the federal 2-year election cycle
Text (4)
FEC''',

'''CmteID
Unique ID given by FEC to each committee.
Text (9)
FEC''',

'''PACShort
Standardized committee name based on PAC's sponsor.
Text (50)
CRP''',

'''Affiliate
Usually blank. For leadpacs, shows the sponsoring member.
Text (50)
CRP''',

'''Ultorg
The standardized parent organization for the organization listed in the PACShort field. If there is no parent identified, this field will be equal to PACShort.
Text (50)
CRP''',

'''RecipID
For candidate committees this will be the candidate's CID. Otherwise, it will be the same as CmteID.
Text (9)
CRP''',

'''RecipCode
A two-character code defining the type of recipient. For candidates, the first character is party ("D" for Democratic, "R" for Republican, "3" for Independent, Libertarian or third party, "U" for Unknown.) The second character is "W" for Winner, "L" for Loser, "I" for incumbent, "C" for Challenger, "O" for "Open Seat", and "N" for Non-incumbent. "N" is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is "P." For PACs, the first character is "P" and for outside spending groups, "O". For both, the second character is "B" for Business, "L" for Labor", "I" for Ideological, "O" for "Other" and "U" for unknown.
Text (2)
CRP''',

'''FECCandID
Unique ID given to candidates by FEC.
Text (9)
FEC''',

'''Party
(D,R,3,I,L) Will be null or empty if committee is not a party, joint fundraising, leadership or candidate committee.
Text (1)
CRP/FEC''',

'''PrimCode
The standard five character code identifying the committee's industry or ideology.
Text (5)
CRP''',

'''Source
Indicates how the PrimCode was determined.
Text (5)
CRP''',

'''Sensitive
If "Y", the committee has significant business in multiple industries, some of which fall under the jurisdiction of specific congressional committees.
Text (1)
CRP''',

'''Foreign
This is a bit field. Off/False indicate that the company is not owned by a foreign entity. Those that are owned by a foreign entity are on/True, sometimes "-1".
Bit
CRP''',

'''Active
Determines if cmte is active in the cycle - 0 is no and 1 is yes
Integer
CRP'''
]

# %%
etl_text_file('cmtes18.txt', cmtes18SchemaStr, 'cmtes18', 'crp')
# Out:
# 2018-10-07 18:44:14,608 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 18:44:16,543 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# put: `/staging/cmtes18/cmtes18.txt': File exists
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE cmtes18;
# INFO  : Compiling command(queryId=hadoop_20181007184421_08d27c2d-eac2-417f-bc0c-0c2a28a95eac): DROP TABLE cmtes18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007184421_08d27c2d-eac2-417f-bc0c-0c2a28a95eac); Time taken: 0.01 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007184421_08d27c2d-eac2-417f-bc0c-0c2a28a95eac): DROP TABLE cmtes18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007184421_08d27c2d-eac2-417f-bc0c-0c2a28a95eac); Time taken: 0.049 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.114 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE cmtes18
# . . . . . . . . . . . . . > (
#  the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# to each committee., orig-datatype Text (9), source FEC',
# e name based on PACs sponsor., orig-datatype Text (50), source CRP',
# eadpacs, shows the sponsoring member., orig-datatype Text (50), source CRP',
# ), source CRP',
# rig-datatype Text (9), source CRP',
#  for Other and U for unknown., orig-datatype Text (2), source CRP',
# andidates by FEC., orig-datatype Text (9), source FEC',
# e committee., orig-datatype Text (1), source CRP/FEC',
#  (5), source CRP',
# ode was determined., orig-datatype Text (5), source CRP',
#  CRP',
# urce CRP',
# active in the cycle - 0 is no and 1 is yes, orig-datatype Integer, source CRP'
# . . . . . . . . . . . . . > )
# 7.836921 from /staging/cmtes18'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/cmtes18';
# INFO  : Compiling command(queryId=hadoop_20181007184421_90a714b4-f859-4847-892f-0c56f3e09e8a): CREATE EXTERNAL TABLE cmtes18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `CmteID` STRING COMMENT 'Unique ID given by FEC to each committee., orig-datatype Text (9), source FEC',
# `PACShort` STRING COMMENT 'Standardized committee name based on PACs sponsor., orig-datatype Text (50), source CRP',
# `Affiliate` STRING COMMENT 'Usually blank. For leadpacs, shows the sponsoring member., orig-datatype Text (50), source CRP',
# `Ultorg` STRING COMMENT 'The standardized parent organization for the organization listed in the PACShort field. If there is no parent identified, this field will be equal to PACShort., orig-datatype Text (50), source CRP',
# `RecipID` STRING COMMENT 'For candidate committees this will be the candidates CID. Otherwise, it will be the same as CmteID., orig-datatype Text (9), source CRP',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `FECCandID` STRING COMMENT 'Unique ID given to candidates by FEC., orig-datatype Text (9), source FEC',
# `Party` STRING COMMENT '(D,R,3,I,L) Will be null or empty if committee is not a party, joint fundraising, leadership or candidate committee., orig-datatype Text (1), source CRP/FEC',
# `PrimCode` STRING COMMENT 'The standard five character code identifying the committees industry or ideology., orig-datatype Text (5), source CRP',
# `Source` STRING COMMENT 'Indicates how the PrimCode was determined., orig-datatype Text (5), source CRP',
# `Sensitive` STRING COMMENT 'If Y, the committee has significant business in multiple industries, some of which fall under the jurisdiction of specific congressional committees., orig-datatype Text (1), source CRP',
# `Foreign` BOOLEAN COMMENT 'This is a bit field. Off/False indicate that the company is not owned by a foreign entity. Those that are owned by a foreign entity are on/True, sometimes -1., orig-datatype Bit, source CRP',
# `Active` INTEGER COMMENT 'Determines if cmte is active in the cycle - 0 is no and 1 is yes, orig-datatype Integer, source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 18:44:17.836921 from /staging/cmtes18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cmtes18'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007184421_90a714b4-f859-4847-892f-0c56f3e09e8a); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007184421_90a714b4-f859-4847-892f-0c56f3e09e8a): CREATE EXTERNAL TABLE cmtes18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `CmteID` STRING COMMENT 'Unique ID given by FEC to each committee., orig-datatype Text (9), source FEC',
# `PACShort` STRING COMMENT 'Standardized committee name based on PACs sponsor., orig-datatype Text (50), source CRP',
# `Affiliate` STRING COMMENT 'Usually blank. For leadpacs, shows the sponsoring member., orig-datatype Text (50), source CRP',
# `Ultorg` STRING COMMENT 'The standardized parent organization for the organization listed in the PACShort field. If there is no parent identified, this field will be equal to PACShort., orig-datatype Text (50), source CRP',
# `RecipID` STRING COMMENT 'For candidate committees this will be the candidates CID. Otherwise, it will be the same as CmteID., orig-datatype Text (9), source CRP',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `FECCandID` STRING COMMENT 'Unique ID given to candidates by FEC., orig-datatype Text (9), source FEC',
# `Party` STRING COMMENT '(D,R,3,I,L) Will be null or empty if committee is not a party, joint fundraising, leadership or candidate committee., orig-datatype Text (1), source CRP/FEC',
# `PrimCode` STRING COMMENT 'The standard five character code identifying the committees industry or ideology., orig-datatype Text (5), source CRP',
# `Source` STRING COMMENT 'Indicates how the PrimCode was determined., orig-datatype Text (5), source CRP',
# `Sensitive` STRING COMMENT 'If Y, the committee has significant business in multiple industries, some of which fall under the jurisdiction of specific congressional committees., orig-datatype Text (1), source CRP',
# `Foreign` BOOLEAN COMMENT 'This is a bit field. Off/False indicate that the company is not owned by a foreign entity. Those that are owned by a foreign entity are on/True, sometimes -1., orig-datatype Bit, source CRP',
# `Active` INTEGER COMMENT 'Determines if cmte is active in the cycle - 0 is no and 1 is yes, orig-datatype Integer, source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 18:44:17.836921 from /staging/cmtes18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/cmtes18'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007184421_90a714b4-f859-4847-892f-0c56f3e09e8a); Time taken: 0.029 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.057 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pq_crp_cmtes18;
# INFO  : Compiling command(queryId=hadoop_20181007184425_542a7bd7-158f-44a0-ab59-34fa9cdeeeb2): DROP TABLE pq_crp_cmtes18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007184425_542a7bd7-158f-44a0-ab59-34fa9cdeeeb2); Time taken: 0.002 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007184425_542a7bd7-158f-44a0-ab59-34fa9cdeeeb2): DROP TABLE pq_crp_cmtes18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007184425_542a7bd7-158f-44a0-ab59-34fa9cdeeeb2); Time taken: 0.006 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE TABLE pq_crp_cmtes18
# 1.709914 from cmtes18'
# . . . . . . . . . . . . . > STORED AS PARQUET
# . . . . . . . . . . . . . > AS SELECT
# . . . . . . . . . . . . . >     `Cycle` AS `Cycle`,
# . . . . . . . . . . . . . >     `CmteID` AS `CmteID`,
# . . . . . . . . . . . . . >     `PACShort` AS `PACShort`,
# . . . . . . . . . . . . . >     `Affiliate` AS `Affiliate`,
# . . . . . . . . . . . . . >     `Ultorg` AS `Ultorg`,
# . . . . . . . . . . . . . >     `RecipID` AS `RecipID`,
# . . . . . . . . . . . . . >     `RecipCode` AS `RecipCode`,
# . . . . . . . . . . . . . >     `FECCandID` AS `FECCandID`,
# . . . . . . . . . . . . . >     `Party` AS `Party`,
# . . . . . . . . . . . . . >     `PrimCode` AS `PrimCode`,
# . . . . . . . . . . . . . >     `Source` AS `Source`,
# . . . . . . . . . . . . . >     `Sensitive` AS `Sensitive`,
# . . . . . . . . . . . . . >     CAST(`Foreign` AS BOOLEAN) AS `Foreign`,
# . . . . . . . . . . . . . >     CAST(`Active` AS INTEGER) AS `Active`
# . . . . . . . . . . . . . > FROM cmtes18;
# INFO  : Compiling command(queryId=hadoop_20181007184425_adb43c36-92c5-4181-b8be-855859824956): CREATE TABLE pq_crp_cmtes18
# COMMENT 'Auto-generated schema at 2018-10-07 18:44:21.709914 from cmtes18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `CmteID` AS `CmteID`,
# `PACShort` AS `PACShort`,
# `Affiliate` AS `Affiliate`,
# `Ultorg` AS `Ultorg`,
# `RecipID` AS `RecipID`,
# `RecipCode` AS `RecipCode`,
# `FECCandID` AS `FECCandID`,
# `Party` AS `Party`,
# `PrimCode` AS `PrimCode`,
# `Source` AS `Source`,
# `Sensitive` AS `Sensitive`,
# CAST(`Foreign` AS BOOLEAN) AS `Foreign`,
# CAST(`Active` AS INTEGER) AS `Active`
# FROM cmtes18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:cycle, type:string, comment:null), FieldSchema(name:cmteid, type:string, comment:null), FieldSchema(name:pacshort, type:string, comment:null), FieldSchema(name:affiliate, type:string, comment:null), FieldSchema(name:ultorg, type:string, comment:null), FieldSchema(name:recipid, type:string, comment:null), FieldSchema(name:recipcode, type:string, comment:null), FieldSchema(name:feccandid, type:string, comment:null), FieldSchema(name:party, type:string, comment:null), FieldSchema(name:primcode, type:string, comment:null), FieldSchema(name:source, type:string, comment:null), FieldSchema(name:sensitive, type:string, comment:null), FieldSchema(name:foreign, type:boolean, comment:null), FieldSchema(name:active, type:int, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007184425_adb43c36-92c5-4181-b8be-855859824956); Time taken: 0.486 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007184425_adb43c36-92c5-4181-b8be-855859824956): CREATE TABLE pq_crp_cmtes18
# COMMENT 'Auto-generated schema at 2018-10-07 18:44:21.709914 from cmtes18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `CmteID` AS `CmteID`,
# `PACShort` AS `PACShort`,
# `Affiliate` AS `Affiliate`,
# `Ultorg` AS `Ultorg`,
# `RecipID` AS `RecipID`,
# `RecipCode` AS `RecipCode`,
# `FECCandID` AS `FECCandID`,
# `Party` AS `Party`,
# `PrimCode` AS `PrimCode`,
# `Source` AS `Source`,
# `Sensitive` AS `Sensitive`,
# CAST(`Foreign` AS BOOLEAN) AS `Foreign`,
# CAST(`Active` AS INTEGER) AS `Active`
# FROM cmtes18
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hadoop_20181007184425_adb43c36-92c5-4181-b8be-855859824956
# INFO  : Total jobs = 3
# INFO  : Launching Job 1 out of 3
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1538954460508_0004
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://cap1:8088/proxy/application_1538954460508_0004/
# INFO  : Starting Job = job_1538954460508_0004, Tracking URL = http://cap1:8088/proxy/application_1538954460508_0004/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1538954460508_0004
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# INFO  : 2018-10-07 18:51:05,681 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2018-10-07 18:51:13,897 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 5.77 sec
# INFO  : MapReduce Total cumulative CPU time: 5 seconds 770 msec
# INFO  : Ended Job = job_1538954460508_0004
# INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
# INFO  : Stage-4 is selected by condition resolver.
# INFO  : Stage-3 is filtered out by condition resolver.
# INFO  : Stage-5 is filtered out by condition resolver.
# INFO  : Starting task [Stage-4:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-44-25_276_12517744467117877-6/-ext-10002 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-44-25_276_12517744467117877-6/-ext-10004
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/pq_crp_cmtes18 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_18-44-25_276_12517744467117877-6/-ext-10002
# INFO  : Starting task [Stage-8:DDL] in serial mode
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1   Cumulative CPU: 5.77 sec   HDFS Read: 2104160 HDFS Write: 1637122 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 5 seconds 770 msec
# INFO  : Completed executing command(queryId=hadoop_20181007184425_adb43c36-92c5-4181-b8be-855859824956); Time taken: 409.309 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (409.804 seconds)
# 0: jdbc:hive2://cap1:10000>
# RING COMMENT 'Last year (even year) of the federal 2-year election cycle';
# INFO  : Compiling command(queryId=hadoop_20181007185115_dcfd7ebf-6fc0-4944-a47e-10e9c2af701e): ALTER TABLE pq_crp_cmtes18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_dcfd7ebf-6fc0-4944-a47e-10e9c2af701e); Time taken: 0.026 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_dcfd7ebf-6fc0-4944-a47e-10e9c2af701e): ALTER TABLE pq_crp_cmtes18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_dcfd7ebf-6fc0-4944-a47e-10e9c2af701e); Time taken: 0.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.086 seconds)
# STRING COMMENT 'Unique ID given by FEC to each committee.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_1e3ad0e6-a654-4f3e-addc-33b099f51b8c): ALTER TABLE pq_crp_cmtes18 CHANGE `CmteID` `CmteID` STRING COMMENT 'Unique ID given by FEC to each committee.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_1e3ad0e6-a654-4f3e-addc-33b099f51b8c); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_1e3ad0e6-a654-4f3e-addc-33b099f51b8c): ALTER TABLE pq_crp_cmtes18 CHANGE `CmteID` `CmteID` STRING COMMENT 'Unique ID given by FEC to each committee.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_1e3ad0e6-a654-4f3e-addc-33b099f51b8c); Time taken: 0.034 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# rt` STRING COMMENT 'Standardized committee name based on PACs sponsor.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_a2e7545c-7bce-4c27-a3ce-343a4689f41f): ALTER TABLE pq_crp_cmtes18 CHANGE `PACShort` `PACShort` STRING COMMENT 'Standardized committee name based on PACs sponsor.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_a2e7545c-7bce-4c27-a3ce-343a4689f41f); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_a2e7545c-7bce-4c27-a3ce-343a4689f41f): ALTER TABLE pq_crp_cmtes18 CHANGE `PACShort` `PACShort` STRING COMMENT 'Standardized committee name based on PACs sponsor.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_a2e7545c-7bce-4c27-a3ce-343a4689f41f); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.058 seconds)
# ;
# INFO  : Compiling command(queryId=hadoop_20181007185115_ed6b0396-f32c-438f-91f6-3dbbb90ee5a4): ALTER TABLE pq_crp_cmtes18 CHANGE `Affiliate` `Affiliate` STRING COMMENT 'Usually blank. For leadpacs, shows the sponsoring member.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_ed6b0396-f32c-438f-91f6-3dbbb90ee5a4); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_ed6b0396-f32c-438f-91f6-3dbbb90ee5a4): ALTER TABLE pq_crp_cmtes18 CHANGE `Affiliate` `Affiliate` STRING COMMENT 'Usually blank. For leadpacs, shows the sponsoring member.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_ed6b0396-f32c-438f-91f6-3dbbb90ee5a4); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.054 seconds)
# al to PACShort.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_388b7855-aa60-4f3c-9130-79c1b90075c3): ALTER TABLE pq_crp_cmtes18 CHANGE `Ultorg` `Ultorg` STRING COMMENT 'The standardized parent organization for the organization listed in the PACShort field. If there is no parent identified, this field will be equal to PACShort.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_388b7855-aa60-4f3c-9130-79c1b90075c3); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_388b7855-aa60-4f3c-9130-79c1b90075c3): ALTER TABLE pq_crp_cmtes18 CHANGE `Ultorg` `Ultorg` STRING COMMENT 'The standardized parent organization for the organization listed in the PACShort field. If there is no parent identified, this field will be equal to PACShort.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_388b7855-aa60-4f3c-9130-79c1b90075c3); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.054 seconds)
# rwise, it will be the same as CmteID.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_1644e70a-9921-475b-8b56-5391871b9075): ALTER TABLE pq_crp_cmtes18 CHANGE `RecipID` `RecipID` STRING COMMENT 'For candidate committees this will be the candidates CID. Otherwise, it will be the same as CmteID.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_1644e70a-9921-475b-8b56-5391871b9075); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_1644e70a-9921-475b-8b56-5391871b9075): ALTER TABLE pq_crp_cmtes18 CHANGE `RecipID` `RecipID` STRING COMMENT 'For candidate committees this will be the candidates CID. Otherwise, it will be the same as CmteID.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_1644e70a-9921-475b-8b56-5391871b9075); Time taken: 0.031 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.053 seconds)
# usiness, L for Labor, I for Ideological, O for Other and U for unknown.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_f152b934-e9df-4077-80d7-db0cac077679): ALTER TABLE pq_crp_cmtes18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_f152b934-e9df-4077-80d7-db0cac077679); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_f152b934-e9df-4077-80d7-db0cac077679): ALTER TABLE pq_crp_cmtes18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_f152b934-e9df-4077-80d7-db0cac077679); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.055 seconds)
# ndID` STRING COMMENT 'Unique ID given to candidates by FEC.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_00613b44-d377-4d95-8449-5c88b5d0397e): ALTER TABLE pq_crp_cmtes18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'Unique ID given to candidates by FEC.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_00613b44-d377-4d95-8449-5c88b5d0397e); Time taken: 0.026 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_00613b44-d377-4d95-8449-5c88b5d0397e): ALTER TABLE pq_crp_cmtes18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'Unique ID given to candidates by FEC.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_00613b44-d377-4d95-8449-5c88b5d0397e); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.068 seconds)
# nt fundraising, leadership or candidate committee.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_d39255ca-59bc-40e1-8ef7-0fca8aa84ec9): ALTER TABLE pq_crp_cmtes18 CHANGE `Party` `Party` STRING COMMENT '(D,R,3,I,L) Will be null or empty if committee is not a party, joint fundraising, leadership or candidate committee.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_d39255ca-59bc-40e1-8ef7-0fca8aa84ec9); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_d39255ca-59bc-40e1-8ef7-0fca8aa84ec9): ALTER TABLE pq_crp_cmtes18 CHANGE `Party` `Party` STRING COMMENT '(D,R,3,I,L) Will be null or empty if committee is not a party, joint fundraising, leadership or candidate committee.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_d39255ca-59bc-40e1-8ef7-0fca8aa84ec9); Time taken: 0.035 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.06 seconds)
# industry or ideology.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_b12cb975-11d7-404b-8003-4fab9a8d2355): ALTER TABLE pq_crp_cmtes18 CHANGE `PrimCode` `PrimCode` STRING COMMENT 'The standard five character code identifying the committees industry or ideology.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_b12cb975-11d7-404b-8003-4fab9a8d2355); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_b12cb975-11d7-404b-8003-4fab9a8d2355): ALTER TABLE pq_crp_cmtes18 CHANGE `PrimCode` `PrimCode` STRING COMMENT 'The standard five character code identifying the committees industry or ideology.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_b12cb975-11d7-404b-8003-4fab9a8d2355); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.076 seconds)
# STRING COMMENT 'Indicates how the PrimCode was determined.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_91d41900-400d-431d-a9e0-f3242d7e34b2): ALTER TABLE pq_crp_cmtes18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the PrimCode was determined.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_91d41900-400d-431d-a9e0-f3242d7e34b2); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_91d41900-400d-431d-a9e0-f3242d7e34b2): ALTER TABLE pq_crp_cmtes18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the PrimCode was determined.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_91d41900-400d-431d-a9e0-f3242d7e34b2); Time taken: 0.031 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.055 seconds)
# ommittees.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_ddbe8a60-1fdf-4afa-86cb-b93366d57313): ALTER TABLE pq_crp_cmtes18 CHANGE `Sensitive` `Sensitive` STRING COMMENT 'If Y, the committee has significant business in multiple industries, some of which fall under the jurisdiction of specific congressional committees.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_ddbe8a60-1fdf-4afa-86cb-b93366d57313); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_ddbe8a60-1fdf-4afa-86cb-b93366d57313): ALTER TABLE pq_crp_cmtes18 CHANGE `Sensitive` `Sensitive` STRING COMMENT 'If Y, the committee has significant business in multiple industries, some of which fall under the jurisdiction of specific congressional committees.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_ddbe8a60-1fdf-4afa-86cb-b93366d57313); Time taken: 0.03 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.053 seconds)
# ue, sometimes -1.';
# INFO  : Compiling command(queryId=hadoop_20181007185115_e58c909e-ed1c-464a-9f7c-ca8baacea1fb): ALTER TABLE pq_crp_cmtes18 CHANGE `Foreign` `Foreign` BOOLEAN COMMENT 'This is a bit field. Off/False indicate that the company is not owned by a foreign entity. Those that are owned by a foreign entity are on/True, sometimes -1.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_e58c909e-ed1c-464a-9f7c-ca8baacea1fb); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_e58c909e-ed1c-464a-9f7c-ca8baacea1fb): ALTER TABLE pq_crp_cmtes18 CHANGE `Foreign` `Foreign` BOOLEAN COMMENT 'This is a bit field. Off/False indicate that the company is not owned by a foreign entity. Those that are owned by a foreign entity are on/True, sometimes -1.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_e58c909e-ed1c-464a-9f7c-ca8baacea1fb); Time taken: 0.034 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.058 seconds)
# s';
# INFO  : Compiling command(queryId=hadoop_20181007185115_a42b60a2-93ab-410e-b689-c1b815fefc71): ALTER TABLE pq_crp_cmtes18 CHANGE `Active` `Active` INTEGER COMMENT 'Determines if cmte is active in the cycle - 0 is no and 1 is yes'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007185115_a42b60a2-93ab-410e-b689-c1b815fefc71); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007185115_a42b60a2-93ab-410e-b689-c1b815fefc71): ALTER TABLE pq_crp_cmtes18 CHANGE `Active` `Active` INTEGER COMMENT 'Determines if cmte is active in the cycle - 0 is no and 1 is yes'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007185115_a42b60a2-93ab-410e-b689-c1b815fefc71); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.057 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# 2018-10-07 18:51:17,200 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/cmtes18
# done

# %%
sc.sql('SELECT * FROM pq_crp_cmtes18').limit(10).show()
# Out:
# +-----+---------+--------------------+--------------------+--------------------+---------+---------+---------+-----+--------+------+---------+-------+------+
# |cycle|   cmteid|            pacshort|           affiliate|              ultorg|  recipid|recipcode|feccandid|party|primcode|source|sensitive|foreign|active|
# +-----+---------+--------------------+--------------------+--------------------+---------+---------+---------+-----+--------+------+---------+-------+------+
# | 2018|C00000018|                    |                    |                    |C00000018|         |H8TX22313|     |        |      |         |  false|     0|
# | 2018|C00000059|      Hallmark Cards|                    |      Hallmark Cards|C00000059|       PB|         |     |   C1400| WebAM|        n|  false|     1|
# | 2018|C00000422|American Medical ...|American Medical ...|American Medical ...|C00000422|       PB|         |     |   H1100| AFP88|        n|  false|     1|
# | 2018|C00000489| Teamsters Local 886|     Teamsters Union|     Teamsters Union|C00000489|       PL|         |     |   LT300|  Name|        N|  false|     1|
# | 2018|C00000547| Kansas Medical Assn|American Medical ...|American Medical ...|C00000547|       PB|         |     |   H1100|  Name|        n|  false|     0|
# | 2018|C00000638|Indiana Medical Assn|American Medical ...|American Medical ...|C00000638|       PB|         |     |   H1100| AFP88|        N|  false|     1|
# | 2018|C00000729|American Dental Assn|American Dental Assn|American Dental Assn|C00000729|       PB|         |     |   H1400| AFP88|        n|  false|     1|
# | 2018|C00000885|Painters & Allied...|Painters & Allied...|Painters & Allied...|C00000885|       PL|         |     |   LB100| AFP99|        N|  false|     1|
# | 2018|C00000901|National Assn of ...|National Assn of ...|National Assn of ...|C00000901|       PB|         |     |   B2000| AFP88|        n|  false|     1|
# | 2018|C00000935|Democratic Congre...|Democratic Congre...|Democratic Congre...|C00000935|       DP|         |    D|   Z5200|  Rept|        n|  false|     1|
# +-----+---------+--------------------+--------------------+--------------------+---------+---------+---------+-----+--------+------+---------+-------+------+

# %%
sc.sql('DESCRIBE TABLE pq_crp_cmtes18').show()
# Out:
# +---------+---------+--------------------+
# | col_name|data_type|             comment|
# +---------+---------+--------------------+
# |    cycle|   string|Last year (even y...|
# |   cmteid|   string|Unique ID given b...|
# | pacshort|   string|Standardized comm...|
# |affiliate|   string|Usually blank. Fo...|
# |   ultorg|   string|The standardized ...|
# |  recipid|   string|For candidate com...|
# |recipcode|   string|A two-character c...|
# |feccandid|   string|Unique ID given t...|
# |    party|   string|(D,R,3,I,L) Will ...|
# | primcode|   string|The standard five...|
# |   source|   string|Indicates how the...|
# |sensitive|   string|If Y, the committ...|
# |  foreign|  boolean|This is a bit fie...|
# |   active|      int|Determines if cmt...|
# +---------+---------+--------------------+

# %% [markdown]
# # `indivs18`

# %% [markdown]
# `indivs18` schema string: https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20for%20Individual%20Contribution%20Data.htm

# %%
indivs18SchemaStr = [
'''Cycle
Last year (even year) of the federal 2-year election cycle
Text (4)
FEC''',

'''FECTransID
A unique record identifier within a given cycle.
Text (19)
FEC''',

'''ContribID
A unique identifier for individual donors.  Family groups match on first 11 chars
Text (12)
CRP''',

'''Contrib
The name of the contributor, usually in the format Last name, First Name.
Text (50)
FEC''',

'''RecipID
The recipient's id number. If the contribution is to a candidate this will be the candidate's unique candidate id number. Otherwise, it will be the FEC committee id number.
Text (9)
CRP''',

'''Orgname
The standardized organization name for the contributor. This is usually based on the donor's employer. The donor may not have an income producing occupation (e.g. homemaker)
Text (50)
CRP''',

'''UltOrg
The standardized parent organization for the organization listed in the Orgname field. If there is no parent identified, this field will be blank or null.
Text (50)
CRP''',

'''RealCode
The standard five character code identifying the donor's industry or ideology. Usually based on Orgname (e.g., the orgname "Microsoft Corp" would normally get realcode C5120 for computer software.)
Text (5)
CRP''',

'''Date
The reported date of the contribution.
MM/DD/YYYY
FEC''',

'''Amount
The amount contributed. This will be negative for refunds.
Integer
FEC''',

'''Street
2000+ cycle only, and only for committees that file electronically
Text (40)
FEC''',

'''City
The donor's city. This could be based on a home address or an employer's address. 
Text (30)
FEC''',

'''State
The donor's state. This could be based on a home address or an employer's address.
Text (2)
FEC''',

'''Zip
The donor's zip code. This could be based on a home address or an employer's address.
Text (5)
FEC''',

'''RecipCode
A two-character code defining the type of recipient. For candidates, the first character is party ("D" for Democratic, "R" for Republican, "3" for Independent, Libertarian or third party, "U" for Unknown.) The second character is "W" for Winner, "L" for Loser, "I" for incumbent, "C" for Challenger, "O" for "Open Seat", and "N" for Non-incumbent. "N" is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is "P." For PACs, the first character is "P" and the second character is "B" for Business, "L" for Labor", "I" for Ideological, "O" for "Other" and "U" for unknown.
Text (2)
CRP''',

'''Type
The transaction type code for the contribution. 15 is a contribution, 15e is an earmarked contribution (made through a group such as Club for Growth or Emily's List), 15j is a contribution through a joint fund raising committee and 22y is a refund. "10" indicates "soft" or nonfederal money for the 2002 cycle and earlier. For the 2004 cycle and later type "10" indicates Levin funds.or outside spending.
Text (3)
FEC''',

'''CmteID
The committee id number for the recipient. Note that a candidate can have more than one committee — this field indicates the exact committee receiving the contribution.
Text (9)
FEC''',

'''OtherID
The committee id number for the intermediary party to earmarked contributions.
Text (9)
FEC''',

'''Gender
The donor's gender. Can also be "U" if unknown or "N" if the name is ambiguous.
Text (1)
CRP''',

'''Microfilm
Refers to specific page of FEC report images on which this transaction appears.
Text (11)
FEC''',

'''Occupation
The donor's disclosed occupation.
Text (38)
FEC''',

'''Employer
The donor's s disclosed employer
Text (38)
FEC''',

'''Source
Indicates how the RealCode was determined — see the How to Use Source in the OpenSecrets OpenData Guide
Text (5)
<NOT SPECIFIED>'''
]

# %%
etl_text_file('indivs18.txt', indivs18SchemaStr, 'indivs18', 'crp', column_datetime_formats={'Date': 'MM/dd/yyyy'})
# Out:
# 2018-10-07 19:47:23,035 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 19:47:24,971 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE indivs18;
# INFO  : Compiling command(queryId=hadoop_20181007194756_cfa7e3b2-c9fd-4f02-b145-592fbc6b1b6e): DROP TABLE indivs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007194756_cfa7e3b2-c9fd-4f02-b145-592fbc6b1b6e); Time taken: 0.01 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007194756_cfa7e3b2-c9fd-4f02-b145-592fbc6b1b6e): DROP TABLE indivs18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007194756_cfa7e3b2-c9fd-4f02-b145-592fbc6b1b6e); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.105 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE indivs18
# . . . . . . . . . . . . . > (
#  the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# ntifier within a given cycle., orig-datatype Text (19), source FEC',
# t (12), source CRP',
# urce FEC',
# ype Text (9), source CRP',
# atype Text (50), source CRP',
# urce CRP',
# er software.), orig-datatype Text (5), source CRP',
# ntribution., orig-datatype MM/DD/YYYY, source FEC',
# . This will be negative for refunds., orig-datatype Integer, source FEC',
# ',
# , source FEC',
# , source FEC',
# ), source FEC',
# pe Text (2), source CRP',
# urce FEC',
#  Text (9), source FEC',
# , source FEC',
# rce CRP',
# (11), source FEC',
# d occupation., orig-datatype Text (38), source FEC',
# d employer, orig-datatype Text (38), source FEC',
# , orig-datatype Text (5), source <NOT SPECIFIED>'
# . . . . . . . . . . . . . > )
# 1.934788 from /staging/indivs18'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/indivs18';
# INFO  : Compiling command(queryId=hadoop_20181007194756_7d9965b7-250b-4ec8-88df-ad33e8305044): CREATE EXTERNAL TABLE indivs18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECTransID` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `ContribID` STRING COMMENT 'A unique identifier for individual donors.  Family groups match on first 11 chars, orig-datatype Text (12), source CRP',
# `Contrib` STRING COMMENT 'The name of the contributor, usually in the format Last name, First Name., orig-datatype Text (50), source FEC',
# `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number., orig-datatype Text (9), source CRP',
# `Orgname` STRING COMMENT 'The standardized organization name for the contributor. This is usually based on the donors employer. The donor may not have an income producing occupation (e.g. homemaker), orig-datatype Text (50), source CRP',
# `UltOrg` STRING COMMENT 'The standardized parent organization for the organization listed in the Orgname field. If there is no parent identified, this field will be blank or null., orig-datatype Text (50), source CRP',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Orgname (e.g., the orgname Microsoft Corp would normally get realcode C5120 for computer software.), orig-datatype Text (5), source CRP',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype MM/DD/YYYY, source FEC',
# `Amount` INTEGER COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype Integer, source FEC',
# `Street` STRING COMMENT '2000+ cycle only, and only for committees that file electronically, orig-datatype Text (40), source FEC',
# `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address. , orig-datatype Text (30), source FEC',
# `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address., orig-datatype Text (2), source FEC',
# `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address., orig-datatype Text (5), source FEC',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 15 is a contribution, 15e is an earmarked contribution (made through a group such as Club for Growth or Emilys List), 15j is a contribution through a joint fund raising committee and 22y is a refund. 10 indicates soft or nonfederal money for the 2002 cycle and earlier. For the 2004 cycle and later type 10 indicates Levin funds.or outside spending., orig-datatype Text (3), source FEC',
# `CmteID` STRING COMMENT 'The committee id number for the recipient. Note that a candidate can have more than one committee — this field indicates the exact committee receiving the contribution., orig-datatype Text (9), source FEC',
# `OtherID` STRING COMMENT 'The committee id number for the intermediary party to earmarked contributions., orig-datatype Text (9), source FEC',
# `Gender` STRING COMMENT 'The donors gender. Can also be U if unknown or N if the name is ambiguous., orig-datatype Text (1), source CRP',
# `Microfilm` STRING COMMENT 'Refers to specific page of FEC report images on which this transaction appears., orig-datatype Text (11), source FEC',
# `Occupation` STRING COMMENT 'The donors disclosed occupation., orig-datatype Text (38), source FEC',
# `Employer` STRING COMMENT 'The donors s disclosed employer, orig-datatype Text (38), source FEC',
# `Source` STRING COMMENT 'Indicates how the RealCode was determined — see the How to Use Source in the OpenSecrets OpenData Guide, orig-datatype Text (5), source <NOT SPECIFIED>'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 19:47:51.934788 from /staging/indivs18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/indivs18'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007194756_7d9965b7-250b-4ec8-88df-ad33e8305044); Time taken: 0.12 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007194756_7d9965b7-250b-4ec8-88df-ad33e8305044): CREATE EXTERNAL TABLE indivs18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECTransID` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `ContribID` STRING COMMENT 'A unique identifier for individual donors.  Family groups match on first 11 chars, orig-datatype Text (12), source CRP',
# `Contrib` STRING COMMENT 'The name of the contributor, usually in the format Last name, First Name., orig-datatype Text (50), source FEC',
# `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number., orig-datatype Text (9), source CRP',
# `Orgname` STRING COMMENT 'The standardized organization name for the contributor. This is usually based on the donors employer. The donor may not have an income producing occupation (e.g. homemaker), orig-datatype Text (50), source CRP',
# `UltOrg` STRING COMMENT 'The standardized parent organization for the organization listed in the Orgname field. If there is no parent identified, this field will be blank or null., orig-datatype Text (50), source CRP',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Orgname (e.g., the orgname Microsoft Corp would normally get realcode C5120 for computer software.), orig-datatype Text (5), source CRP',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype MM/DD/YYYY, source FEC',
# `Amount` INTEGER COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype Integer, source FEC',
# `Street` STRING COMMENT '2000+ cycle only, and only for committees that file electronically, orig-datatype Text (40), source FEC',
# `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address. , orig-datatype Text (30), source FEC',
# `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address., orig-datatype Text (2), source FEC',
# `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address., orig-datatype Text (5), source FEC',
# `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 15 is a contribution, 15e is an earmarked contribution (made through a group such as Club for Growth or Emilys List), 15j is a contribution through a joint fund raising committee and 22y is a refund. 10 indicates soft or nonfederal money for the 2002 cycle and earlier. For the 2004 cycle and later type 10 indicates Levin funds.or outside spending., orig-datatype Text (3), source FEC',
# `CmteID` STRING COMMENT 'The committee id number for the recipient. Note that a candidate can have more than one committee — this field indicates the exact committee receiving the contribution., orig-datatype Text (9), source FEC',
# `OtherID` STRING COMMENT 'The committee id number for the intermediary party to earmarked contributions., orig-datatype Text (9), source FEC',
# `Gender` STRING COMMENT 'The donors gender. Can also be U if unknown or N if the name is ambiguous., orig-datatype Text (1), source CRP',
# `Microfilm` STRING COMMENT 'Refers to specific page of FEC report images on which this transaction appears., orig-datatype Text (11), source FEC',
# `Occupation` STRING COMMENT 'The donors disclosed occupation., orig-datatype Text (38), source FEC',
# `Employer` STRING COMMENT 'The donors s disclosed employer, orig-datatype Text (38), source FEC',
# `Source` STRING COMMENT 'Indicates how the RealCode was determined — see the How to Use Source in the OpenSecrets OpenData Guide, orig-datatype Text (5), source <NOT SPECIFIED>'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 19:47:51.934788 from /staging/indivs18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/indivs18'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007194756_7d9965b7-250b-4ec8-88df-ad33e8305044); Time taken: 1.737 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (1.874 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pq_crp_indivs18;
# INFO  : Compiling command(queryId=hadoop_20181007194801_9bc8aa1f-f482-468c-8305-c8fc6308f0ad): DROP TABLE pq_crp_indivs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007194801_9bc8aa1f-f482-468c-8305-c8fc6308f0ad); Time taken: 0.022 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007194801_9bc8aa1f-f482-468c-8305-c8fc6308f0ad): DROP TABLE pq_crp_indivs18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007194801_9bc8aa1f-f482-468c-8305-c8fc6308f0ad); Time taken: 0.2 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.293 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE TABLE pq_crp_indivs18
# 8.392977 from indivs18'
# . . . . . . . . . . . . . > STORED AS PARQUET
# . . . . . . . . . . . . . > AS SELECT
# . . . . . . . . . . . . . >     `Cycle` AS `Cycle`,
# . . . . . . . . . . . . . >     `FECTransID` AS `FECTransID`,
# . . . . . . . . . . . . . >     `ContribID` AS `ContribID`,
# . . . . . . . . . . . . . >     `Contrib` AS `Contrib`,
# . . . . . . . . . . . . . >     `RecipID` AS `RecipID`,
# . . . . . . . . . . . . . >     `Orgname` AS `Orgname`,
# . . . . . . . . . . . . . >     `UltOrg` AS `UltOrg`,
# . . . . . . . . . . . . . >     `RealCode` AS `RealCode`,
# /dd/yyyy'))) AS `Date`,
# . . . . . . . . . . . . . >     CAST(`Amount` AS INTEGER) AS `Amount`,
# . . . . . . . . . . . . . >     `Street` AS `Street`,
# . . . . . . . . . . . . . >     `City` AS `City`,
# . . . . . . . . . . . . . >     `State` AS `State`,
# . . . . . . . . . . . . . >     `Zip` AS `Zip`,
# . . . . . . . . . . . . . >     `RecipCode` AS `RecipCode`,
# . . . . . . . . . . . . . >     `Type` AS `Type`,
# . . . . . . . . . . . . . >     `CmteID` AS `CmteID`,
# . . . . . . . . . . . . . >     `OtherID` AS `OtherID`,
# . . . . . . . . . . . . . >     `Gender` AS `Gender`,
# . . . . . . . . . . . . . >     `Microfilm` AS `Microfilm`,
# . . . . . . . . . . . . . >     `Occupation` AS `Occupation`,
# . . . . . . . . . . . . . >     `Employer` AS `Employer`,
# . . . . . . . . . . . . . >     `Source` AS `Source`
# . . . . . . . . . . . . . > FROM indivs18;
# INFO  : Compiling command(queryId=hadoop_20181007194802_e9fa689d-8d07-46f2-963e-bf723c6eae46): CREATE TABLE pq_crp_indivs18
# COMMENT 'Auto-generated schema at 2018-10-07 19:47:58.392977 from indivs18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECTransID` AS `FECTransID`,
# `ContribID` AS `ContribID`,
# `Contrib` AS `Contrib`,
# `RecipID` AS `RecipID`,
# `Orgname` AS `Orgname`,
# `UltOrg` AS `UltOrg`,
# `RealCode` AS `RealCode`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# CAST(`Amount` AS INTEGER) AS `Amount`,
# `Street` AS `Street`,
# `City` AS `City`,
# `State` AS `State`,
# `Zip` AS `Zip`,
# `RecipCode` AS `RecipCode`,
# `Type` AS `Type`,
# `CmteID` AS `CmteID`,
# `OtherID` AS `OtherID`,
# `Gender` AS `Gender`,
# `Microfilm` AS `Microfilm`,
# `Occupation` AS `Occupation`,
# `Employer` AS `Employer`,
# `Source` AS `Source`
# FROM indivs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:cycle, type:string, comment:null), FieldSchema(name:fectransid, type:string, comment:null), FieldSchema(name:contribid, type:string, comment:null), FieldSchema(name:contrib, type:string, comment:null), FieldSchema(name:recipid, type:string, comment:null), FieldSchema(name:orgname, type:string, comment:null), FieldSchema(name:ultorg, type:string, comment:null), FieldSchema(name:realcode, type:string, comment:null), FieldSchema(name:date, type:date, comment:null), FieldSchema(name:amount, type:int, comment:null), FieldSchema(name:street, type:string, comment:null), FieldSchema(name:city, type:string, comment:null), FieldSchema(name:state, type:string, comment:null), FieldSchema(name:zip, type:string, comment:null), FieldSchema(name:recipcode, type:string, comment:null), FieldSchema(name:type, type:string, comment:null), FieldSchema(name:cmteid, type:string, comment:null), FieldSchema(name:otherid, type:string, comment:null), FieldSchema(name:gender, type:string, comment:null), FieldSchema(name:microfilm, type:string, comment:null), FieldSchema(name:occupation, type:string, comment:null), FieldSchema(name:employer, type:string, comment:null), FieldSchema(name:source, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007194802_e9fa689d-8d07-46f2-963e-bf723c6eae46); Time taken: 1.967 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007194802_e9fa689d-8d07-46f2-963e-bf723c6eae46): CREATE TABLE pq_crp_indivs18
# COMMENT 'Auto-generated schema at 2018-10-07 19:47:58.392977 from indivs18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECTransID` AS `FECTransID`,
# `ContribID` AS `ContribID`,
# `Contrib` AS `Contrib`,
# `RecipID` AS `RecipID`,
# `Orgname` AS `Orgname`,
# `UltOrg` AS `UltOrg`,
# `RealCode` AS `RealCode`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# CAST(`Amount` AS INTEGER) AS `Amount`,
# `Street` AS `Street`,
# `City` AS `City`,
# `State` AS `State`,
# `Zip` AS `Zip`,
# `RecipCode` AS `RecipCode`,
# `Type` AS `Type`,
# `CmteID` AS `CmteID`,
# `OtherID` AS `OtherID`,
# `Gender` AS `Gender`,
# `Microfilm` AS `Microfilm`,
# `Occupation` AS `Occupation`,
# `Employer` AS `Employer`,
# `Source` AS `Source`
# FROM indivs18
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hadoop_20181007194802_e9fa689d-8d07-46f2-963e-bf723c6eae46
# INFO  : Total jobs = 3
# INFO  : Launching Job 1 out of 3
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:10
# INFO  : Submitting tokens for job: job_1538957855726_0003
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://cap1:8088/proxy/application_1538957855726_0003/
# INFO  : Starting Job = job_1538957855726_0003, Tracking URL = http://cap1:8088/proxy/application_1538957855726_0003/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1538957855726_0003
# INFO  : Hadoop job information for Stage-1: number of mappers: 10; number of reducers: 0
# INFO  : 2018-10-07 19:48:12,772 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2018-10-07 19:48:42,733 Stage-1 map = 20%,  reduce = 0%, Cumulative CPU 127.25 sec
# INFO  : 2018-10-07 19:48:52,999 Stage-1 map = 25%,  reduce = 0%, Cumulative CPU 167.23 sec
# INFO  : 2018-10-07 19:48:55,054 Stage-1 map = 30%,  reduce = 0%, Cumulative CPU 186.68 sec
# INFO  : 2018-10-07 19:48:58,147 Stage-1 map = 35%,  reduce = 0%, Cumulative CPU 190.22 sec
# INFO  : 2018-10-07 19:49:00,206 Stage-1 map = 40%,  reduce = 0%, Cumulative CPU 193.81 sec
# INFO  : 2018-10-07 19:49:16,622 Stage-1 map = 45%,  reduce = 0%, Cumulative CPU 286.12 sec
# INFO  : 2018-10-07 19:49:20,732 Stage-1 map = 50%,  reduce = 0%, Cumulative CPU 306.55 sec
# INFO  : 2018-10-07 19:49:24,831 Stage-1 map = 55%,  reduce = 0%, Cumulative CPU 319.98 sec
# INFO  : 2018-10-07 19:49:26,878 Stage-1 map = 60%,  reduce = 0%, Cumulative CPU 333.34 sec
# INFO  : 2018-10-07 19:49:30,981 Stage-1 map = 65%,  reduce = 0%, Cumulative CPU 353.94 sec
# INFO  : 2018-10-07 19:49:34,067 Stage-1 map = 70%,  reduce = 0%, Cumulative CPU 366.32 sec
# INFO  : 2018-10-07 19:49:38,161 Stage-1 map = 75%,  reduce = 0%, Cumulative CPU 374.96 sec
# INFO  : 2018-10-07 19:49:41,234 Stage-1 map = 80%,  reduce = 0%, Cumulative CPU 385.63 sec
# INFO  : 2018-10-07 19:49:51,467 Stage-1 map = 85%,  reduce = 0%, Cumulative CPU 430.77 sec
# INFO  : 2018-10-07 19:49:52,489 Stage-1 map = 95%,  reduce = 0%, Cumulative CPU 434.83 sec
# INFO  : 2018-10-07 19:50:07,847 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 455.92 sec
# INFO  : MapReduce Total cumulative CPU time: 7 minutes 35 seconds 920 msec
# INFO  : Ended Job = job_1538957855726_0003
# INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
# INFO  : Stage-4 is selected by condition resolver.
# INFO  : Stage-3 is filtered out by condition resolver.
# INFO  : Stage-5 is filtered out by condition resolver.
# INFO  : Starting task [Stage-4:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-48-02_165_8801336493153482195-2/-ext-10002 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-48-02_165_8801336493153482195-2/-ext-10004
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/pq_crp_indivs18 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-48-02_165_8801336493153482195-2/-ext-10002
# INFO  : Starting task [Stage-8:DDL] in serial mode
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 10   Cumulative CPU: 455.92 sec   HDFS Read: 2515048593 HDFS Write: 1284758195 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 7 minutes 35 seconds 920 msec
# INFO  : Completed executing command(queryId=hadoop_20181007194802_e9fa689d-8d07-46f2-963e-bf723c6eae46); Time taken: 127.139 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (129.119 seconds)
# 0: jdbc:hive2://cap1:10000>
# TRING COMMENT 'Last year (even year) of the federal 2-year election cycle';
# INFO  : Compiling command(queryId=hadoop_20181007195011_854eb8d6-b22b-4b96-a4ae-bac903037e8e): ALTER TABLE pq_crp_indivs18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_854eb8d6-b22b-4b96-a4ae-bac903037e8e); Time taken: 0.026 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_854eb8d6-b22b-4b96-a4ae-bac903037e8e): ALTER TABLE pq_crp_indivs18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_854eb8d6-b22b-4b96-a4ae-bac903037e8e); Time taken: 0.047 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.085 seconds)
# TransID` STRING COMMENT 'A unique record identifier within a given cycle.';
# INFO  : Compiling command(queryId=hadoop_20181007195011_bd4a64f3-171f-4690-8f9b-134f76361326): ALTER TABLE pq_crp_indivs18 CHANGE `FECTransID` `FECTransID` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_bd4a64f3-171f-4690-8f9b-134f76361326); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_bd4a64f3-171f-4690-8f9b-134f76361326): ALTER TABLE pq_crp_indivs18 CHANGE `FECTransID` `FECTransID` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_bd4a64f3-171f-4690-8f9b-134f76361326); Time taken: 0.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.079 seconds)
#  match on first 11 chars';
# INFO  : Compiling command(queryId=hadoop_20181007195011_832233fc-a6ac-4084-bd74-2b5f843029dc): ALTER TABLE pq_crp_indivs18 CHANGE `ContribID` `ContribID` STRING COMMENT 'A unique identifier for individual donors.  Family groups match on first 11 chars'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_832233fc-a6ac-4084-bd74-2b5f843029dc); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_832233fc-a6ac-4084-bd74-2b5f843029dc): ALTER TABLE pq_crp_indivs18 CHANGE `ContribID` `ContribID` STRING COMMENT 'A unique identifier for individual donors.  Family groups match on first 11 chars'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_832233fc-a6ac-4084-bd74-2b5f843029dc); Time taken: 0.044 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.071 seconds)
#  First Name.';
# INFO  : Compiling command(queryId=hadoop_20181007195011_7d82ec86-8d52-45ef-8a04-5e4f2e6bd56b): ALTER TABLE pq_crp_indivs18 CHANGE `Contrib` `Contrib` STRING COMMENT 'The name of the contributor, usually in the format Last name, First Name.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_7d82ec86-8d52-45ef-8a04-5e4f2e6bd56b); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_7d82ec86-8d52-45ef-8a04-5e4f2e6bd56b): ALTER TABLE pq_crp_indivs18 CHANGE `Contrib` `Contrib` STRING COMMENT 'The name of the contributor, usually in the format Last name, First Name.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_7d82ec86-8d52-45ef-8a04-5e4f2e6bd56b); Time taken: 0.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.07 seconds)
#  the FEC committee id number.';
# INFO  : Compiling command(queryId=hadoop_20181007195011_eb3af36b-7b54-4184-83f5-1470429540ee): ALTER TABLE pq_crp_indivs18 CHANGE `RecipID` `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_eb3af36b-7b54-4184-83f5-1470429540ee); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_eb3af36b-7b54-4184-83f5-1470429540ee): ALTER TABLE pq_crp_indivs18 CHANGE `RecipID` `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_eb3af36b-7b54-4184-83f5-1470429540ee); Time taken: 0.041 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.069 seconds)
# ing occupation (e.g. homemaker)';
# INFO  : Compiling command(queryId=hadoop_20181007195011_ce576f99-3f4d-418e-81fc-a6f32a96d5d7): ALTER TABLE pq_crp_indivs18 CHANGE `Orgname` `Orgname` STRING COMMENT 'The standardized organization name for the contributor. This is usually based on the donors employer. The donor may not have an income producing occupation (e.g. homemaker)'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_ce576f99-3f4d-418e-81fc-a6f32a96d5d7); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_ce576f99-3f4d-418e-81fc-a6f32a96d5d7): ALTER TABLE pq_crp_indivs18 CHANGE `Orgname` `Orgname` STRING COMMENT 'The standardized organization name for the contributor. This is usually based on the donors employer. The donor may not have an income producing occupation (e.g. homemaker)'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_ce576f99-3f4d-418e-81fc-a6f32a96d5d7); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.068 seconds)
# nk or null.';
# INFO  : Compiling command(queryId=hadoop_20181007195011_3e71e93f-c334-4819-8101-c41f6103d311): ALTER TABLE pq_crp_indivs18 CHANGE `UltOrg` `UltOrg` STRING COMMENT 'The standardized parent organization for the organization listed in the Orgname field. If there is no parent identified, this field will be blank or null.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_3e71e93f-c334-4819-8101-c41f6103d311); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_3e71e93f-c334-4819-8101-c41f6103d311): ALTER TABLE pq_crp_indivs18 CHANGE `UltOrg` `UltOrg` STRING COMMENT 'The standardized parent organization for the organization listed in the Orgname field. If there is no parent identified, this field will be blank or null.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_3e71e93f-c334-4819-8101-c41f6103d311); Time taken: 0.04 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.07 seconds)
# uld normally get realcode C5120 for computer software.)';
# INFO  : Compiling command(queryId=hadoop_20181007195011_f1ec4885-7c3e-49bd-b815-8ec7d0b6ccc5): ALTER TABLE pq_crp_indivs18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Orgname (e.g., the orgname Microsoft Corp would normally get realcode C5120 for computer software.)'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_f1ec4885-7c3e-49bd-b815-8ec7d0b6ccc5); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_f1ec4885-7c3e-49bd-b815-8ec7d0b6ccc5): ALTER TABLE pq_crp_indivs18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Orgname (e.g., the orgname Microsoft Corp would normally get realcode C5120 for computer software.)'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_f1ec4885-7c3e-49bd-b815-8ec7d0b6ccc5); Time taken: 0.04 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.071 seconds)
# E COMMENT 'The reported date of the contribution.';
# INFO  : Compiling command(queryId=hadoop_20181007195011_db38cea3-cd77-43b0-8112-5ab2b084e011): ALTER TABLE pq_crp_indivs18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195011_db38cea3-cd77-43b0-8112-5ab2b084e011); Time taken: 0.019 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195011_db38cea3-cd77-43b0-8112-5ab2b084e011): ALTER TABLE pq_crp_indivs18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195011_db38cea3-cd77-43b0-8112-5ab2b084e011); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.078 seconds)
#  INTEGER COMMENT 'The amount contributed. This will be negative for refunds.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_6c25920b-ff9d-41b0-a455-7365abc99261): ALTER TABLE pq_crp_indivs18 CHANGE `Amount` `Amount` INTEGER COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_6c25920b-ff9d-41b0-a455-7365abc99261); Time taken: 0.02 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_6c25920b-ff9d-41b0-a455-7365abc99261): ALTER TABLE pq_crp_indivs18 CHANGE `Amount` `Amount` INTEGER COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_6c25920b-ff9d-41b0-a455-7365abc99261); Time taken: 0.039 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.067 seconds)
# lly';
# INFO  : Compiling command(queryId=hadoop_20181007195012_9115c931-a124-4174-a2de-36ae68a7b70b): ALTER TABLE pq_crp_indivs18 CHANGE `Street` `Street` STRING COMMENT '2000+ cycle only, and only for committees that file electronically'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_9115c931-a124-4174-a2de-36ae68a7b70b); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_9115c931-a124-4174-a2de-36ae68a7b70b): ALTER TABLE pq_crp_indivs18 CHANGE `Street` `Street` STRING COMMENT '2000+ cycle only, and only for committees that file electronically'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_9115c931-a124-4174-a2de-36ae68a7b70b); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# ers address. ';
# INFO  : Compiling command(queryId=hadoop_20181007195012_4800776b-7580-4397-b883-73dec3883f96): ALTER TABLE pq_crp_indivs18 CHANGE `City` `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address. '
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_4800776b-7580-4397-b883-73dec3883f96); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_4800776b-7580-4397-b883-73dec3883f96): ALTER TABLE pq_crp_indivs18 CHANGE `City` `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address. '
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_4800776b-7580-4397-b883-73dec3883f96); Time taken: 0.037 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# loyers address.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_512123a0-6c5f-4eef-97d9-b9989467d626): ALTER TABLE pq_crp_indivs18 CHANGE `State` `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_512123a0-6c5f-4eef-97d9-b9989467d626); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_512123a0-6c5f-4eef-97d9-b9989467d626): ALTER TABLE pq_crp_indivs18 CHANGE `State` `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_512123a0-6c5f-4eef-97d9-b9989467d626); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.062 seconds)
# oyers address.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_9d273d85-305d-4f45-88f0-2f05d2a54626): ALTER TABLE pq_crp_indivs18 CHANGE `Zip` `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_9d273d85-305d-4f45-88f0-2f05d2a54626); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_9d273d85-305d-4f45-88f0-2f05d2a54626): ALTER TABLE pq_crp_indivs18 CHANGE `Zip` `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_9d273d85-305d-4f45-88f0-2f05d2a54626); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# O for Other and U for unknown.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_689260ef-b5cf-4481-8e8c-8808a182a69f): ALTER TABLE pq_crp_indivs18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_689260ef-b5cf-4481-8e8c-8808a182a69f); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_689260ef-b5cf-4481-8e8c-8808a182a69f): ALTER TABLE pq_crp_indivs18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two-character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_689260ef-b5cf-4481-8e8c-8808a182a69f); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
#  spending.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_2480c7bb-4925-41eb-a1e9-aceb1a96d5bf): ALTER TABLE pq_crp_indivs18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 15 is a contribution, 15e is an earmarked contribution (made through a group such as Club for Growth or Emilys List), 15j is a contribution through a joint fund raising committee and 22y is a refund. 10 indicates soft or nonfederal money for the 2002 cycle and earlier. For the 2004 cycle and later type 10 indicates Levin funds.or outside spending.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_2480c7bb-4925-41eb-a1e9-aceb1a96d5bf); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_2480c7bb-4925-41eb-a1e9-aceb1a96d5bf): ALTER TABLE pq_crp_indivs18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 15 is a contribution, 15e is an earmarked contribution (made through a group such as Club for Growth or Emilys List), 15j is a contribution through a joint fund raising committee and 22y is a refund. 10 indicates soft or nonfederal money for the 2002 cycle and earlier. For the 2004 cycle and later type 10 indicates Levin funds.or outside spending.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_2480c7bb-4925-41eb-a1e9-aceb1a96d5bf); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.076 seconds)
# ceiving the contribution.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_28672816-cc6e-4e98-9c78-1274b36e2ce0): ALTER TABLE pq_crp_indivs18 CHANGE `CmteID` `CmteID` STRING COMMENT 'The committee id number for the recipient. Note that a candidate can have more than one committee — this field indicates the exact committee receiving the contribution.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_28672816-cc6e-4e98-9c78-1274b36e2ce0); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_28672816-cc6e-4e98-9c78-1274b36e2ce0): ALTER TABLE pq_crp_indivs18 CHANGE `CmteID` `CmteID` STRING COMMENT 'The committee id number for the recipient. Note that a candidate can have more than one committee — this field indicates the exact committee receiving the contribution.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_28672816-cc6e-4e98-9c78-1274b36e2ce0); Time taken: 0.035 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.061 seconds)
# ed contributions.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_d33e98ca-db51-4fb3-8012-53ca8f101506): ALTER TABLE pq_crp_indivs18 CHANGE `OtherID` `OtherID` STRING COMMENT 'The committee id number for the intermediary party to earmarked contributions.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_d33e98ca-db51-4fb3-8012-53ca8f101506); Time taken: 0.017 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_d33e98ca-db51-4fb3-8012-53ca8f101506): ALTER TABLE pq_crp_indivs18 CHANGE `OtherID` `OtherID` STRING COMMENT 'The committee id number for the intermediary party to earmarked contributions.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_d33e98ca-db51-4fb3-8012-53ca8f101506); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.063 seconds)
#  ambiguous.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_c8977536-aabd-40d1-817c-6a7574024253): ALTER TABLE pq_crp_indivs18 CHANGE `Gender` `Gender` STRING COMMENT 'The donors gender. Can also be U if unknown or N if the name is ambiguous.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_c8977536-aabd-40d1-817c-6a7574024253); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_c8977536-aabd-40d1-817c-6a7574024253): ALTER TABLE pq_crp_indivs18 CHANGE `Gender` `Gender` STRING COMMENT 'The donors gender. Can also be U if unknown or N if the name is ambiguous.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_c8977536-aabd-40d1-817c-6a7574024253); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# s transaction appears.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_4e23f5ec-f9ab-423d-8497-6ee8849386b7): ALTER TABLE pq_crp_indivs18 CHANGE `Microfilm` `Microfilm` STRING COMMENT 'Refers to specific page of FEC report images on which this transaction appears.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_4e23f5ec-f9ab-423d-8497-6ee8849386b7); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_4e23f5ec-f9ab-423d-8497-6ee8849386b7): ALTER TABLE pq_crp_indivs18 CHANGE `Microfilm` `Microfilm` STRING COMMENT 'Refers to specific page of FEC report images on which this transaction appears.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_4e23f5ec-f9ab-423d-8497-6ee8849386b7); Time taken: 0.037 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.061 seconds)
# upation` STRING COMMENT 'The donors disclosed occupation.';
# INFO  : Compiling command(queryId=hadoop_20181007195012_e05d9f37-eee4-4dd4-a9ce-efc472ddb50c): ALTER TABLE pq_crp_indivs18 CHANGE `Occupation` `Occupation` STRING COMMENT 'The donors disclosed occupation.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_e05d9f37-eee4-4dd4-a9ce-efc472ddb50c); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_e05d9f37-eee4-4dd4-a9ce-efc472ddb50c): ALTER TABLE pq_crp_indivs18 CHANGE `Occupation` `Occupation` STRING COMMENT 'The donors disclosed occupation.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_e05d9f37-eee4-4dd4-a9ce-efc472ddb50c); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# yer` STRING COMMENT 'The donors s disclosed employer';
# INFO  : Compiling command(queryId=hadoop_20181007195012_18bc2bef-ff4c-4dc9-8662-0a4265e8d9cf): ALTER TABLE pq_crp_indivs18 CHANGE `Employer` `Employer` STRING COMMENT 'The donors s disclosed employer'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_18bc2bef-ff4c-4dc9-8662-0a4265e8d9cf); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_18bc2bef-ff4c-4dc9-8662-0a4265e8d9cf): ALTER TABLE pq_crp_indivs18 CHANGE `Employer` `Employer` STRING COMMENT 'The donors s disclosed employer'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_18bc2bef-ff4c-4dc9-8662-0a4265e8d9cf); Time taken: 0.034 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.058 seconds)
# Source in the OpenSecrets OpenData Guide';
# INFO  : Compiling command(queryId=hadoop_20181007195012_82987b0d-5933-40e3-8dba-b77a691b50f9): ALTER TABLE pq_crp_indivs18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the RealCode was determined — see the How to Use Source in the OpenSecrets OpenData Guide'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195012_82987b0d-5933-40e3-8dba-b77a691b50f9); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195012_82987b0d-5933-40e3-8dba-b77a691b50f9): ALTER TABLE pq_crp_indivs18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the RealCode was determined — see the How to Use Source in the OpenSecrets OpenData Guide'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195012_82987b0d-5933-40e3-8dba-b77a691b50f9); Time taken: 0.048 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.072 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# 2018-10-07 19:50:13,934 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/indivs18
# done

# %%
sc.sql('SELECT * FROM pq_crp_indivs18').limit(10).show()
# Out:
# +-----+-------------------+------------+-------------------+---------+-------+------+--------+----------+------+------+---------+-----+-----+---------+----+---------+---------+------+------------------+------------------+------------+------+
# |cycle|         fectransid|   contribid|            contrib|  recipid|orgname|ultorg|realcode|      date|amount|street|     city|state|  zip|recipcode|type|   cmteid|  otherid|gender|         microfilm|        occupation|    employer|source|
# +-----+-------------------+------------+-------------------+---------+-------+------+--------+----------+------+------+---------+-----+-----+---------+----+---------+---------+------+------------------+------------------+------------+------+
# | 2018|4021520181504779816|p0003541768 |WUTHRICH, STEPHANIE|C00603084|       |      |   J1200|2017-11-08|     5|      |  ELKHART|   IN|46514|       PI| 15E|C00603084|C00401224|     F|201801319091098155|      NOT EMPLOYED|        NONE| P/PAC|
# | 2018|4021520181504779818|p0003541768 |WUTHRICH, STEPHANIE|C00603084|       |      |   J1200|2017-11-08|    10|      |  ELKHART|   IN|46514|       PI| 15E|C00603084|C00401224|     F|201801319091098155|      NOT EMPLOYED|        NONE| P/PAC|
# | 2018|4021520181504779906|U0000003641 |        YORKIN, PEG|C00603084|       |      |   J1200|2017-07-04|    50|      |   MALIBU|   CA|90265|       PI| 15E|C00603084|C00401224|     F|201801319091098185|              NONE|     RETIRED| P/PAC|
# | 2018|4021520181504779918|U0000003641 |        YORKIN, PEG|C00603084|       |      |   J1200|2017-07-06|    50|      |   MALIBU|   CA|90265|       PI| 15E|C00603084|C00401224|     F|201801319091098189|              NONE|     RETIRED| P/PAC|
# | 2018|4021520181504779956|p0003071674 |        YOUNG, ILSE|C00603084|       |      |   J1200|2017-09-11|    50|      |CHAPPAQUA|   NY|10514|       PI| 15E|C00603084|C00401224|     F|201801319091098201|      NOT EMPLOYED|NOT EMPLOYED| P/PAC|
# | 2018|4021520181504779971|i3003383187@|      YOUNG, LILLIE|C00603084|       |      |   J1200|2017-08-12|    15|      |  CHICAGO|   IL|60618|       PI| 15E|C00603084|C00401224|     F|201801319091098206|OFFICE COORDINATOR|       NAPCA| P/PAC|
# | 2018|4021520181504780037|m0002193656 |     ZACCONE, WANDA|C00603084|       |      |   J1200|2017-07-09|    15|      |HENDERSON|   NV|89052|       PI| 15E|C00603084|C00401224|     F|201801319091098228|      NOT EMPLOYED|NOT EMPLOYED| P/PAC|
# | 2018|4021520181504780039|m0002193656 |     ZACCONE, WANDA|C00603084|       |      |   J1200|2017-07-14|     5|      |HENDERSON|   NV|89052|       PI| 15E|C00603084|C00401224|     F|201801319091098229|      NOT EMPLOYED|NOT EMPLOYED| P/PAC|
# | 2018|4021520181504780069|m0002193656 |     ZACCONE, WANDA|C00603084|       |      |   J1200|2017-08-28|     5|      |HENDERSON|   NV|89052|       PI| 15E|C00603084|C00401224|     F|201801319091098239|      NOT EMPLOYED|NOT EMPLOYED| P/PAC|
# | 2018|4021520181504780107|m0002193656 |     ZACCONE, WANDA|C00603084|       |      |   J1200|2017-10-28|     5|      |HENDERSON|   NV|89052|       PI| 15E|C00603084|C00401224|     F|201801319091098252|      NOT EMPLOYED|NOT EMPLOYED| P/PAC|
# +-----+-------------------+------------+-------------------+---------+-------+------+--------+----------+------+------+---------+-----+-----+---------+----+---------+---------+------+------------------+------------------+------------+------+

# %%
sc.sql('DESCRIBE TABLE pq_crp_indivs18').show()
# Out:
# +----------+---------+--------------------+
# |  col_name|data_type|             comment|
# +----------+---------+--------------------+
# |     cycle|   string|Last year (even y...|
# |fectransid|   string|A unique record i...|
# | contribid|   string|A unique identifi...|
# |   contrib|   string|The name of the c...|
# |   recipid|   string|The recipients id...|
# |   orgname|   string|The standardized ...|
# |    ultorg|   string|The standardized ...|
# |  realcode|   string|The standard five...|
# |      date|     date|The reported date...|
# |    amount|      int|The amount contri...|
# |    street|   string|2000+ cycle only,...|
# |      city|   string|The donors city. ...|
# |     state|   string|The donors state....|
# |       zip|   string|The donors zip co...|
# | recipcode|   string|A two-character c...|
# |      type|   string|The transaction t...|
# |    cmteid|   string|The committee id ...|
# |   otherid|   string|The committee id ...|
# |    gender|   string|The donors gender...|
# | microfilm|   string|Refers to specifi...|
# +----------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # `pac_other18`

# %% [markdown]
# `pac_other18` schema string: https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20PAC%20to%20PAC%20Data.htm

# %%
pac_other18SchemaStr = ['''Cycle
Last year (even year) of the federal 2-year election cycle
Text (4)
FEC''',

'''FECRecNo
A unique record identifier within a given cycle.
Text (19)
FEC''',

'''Filerid
The committee id number for the PAC making the filing. Refers to donor if Type 2* or recipient if Type=1*.
Text (9)
FEC''',

'''DonorCmte
The standardized name for the donor based on the name of the PAC's sponsor.
Text (50)
CRP''',

'''ContribLendTrans
Reported name of the donor if Type=1* or the recipient if Type=2*.
Text (50)
FEC''',

'''City
The donor's city. This could be based on a home address or an employer's address.
Text (30)
FEC''',

'''State
The donor's state. This could be based on a home address or an employer's address.
Text (2)
FEC''',

'''Zip
The donor's zip code. This could be based on a home address or an employer's address.
Text (5)
FEC''',

'''FECOccEmp
The donor's disclosed employer and/or occupation.
Text (38)
FEC''',

'''Primcode
The primary industry/ideological code for the donor PAC's sponsor.
Text (5)
CRP''',

'''Date
The reported date of the contribution.
Date
FEC''',

'''Amount
The amount contributed. This will be negative for refunds.
Float
FEC''',

'''RecipID
The recipient's id number. If the contribution is to a candidate this will be the candidate's unique candidate id number. Otherwise, it will be the FEC committee id number.
Text (9)
CRP''',

'''Party
The party (if any) of the recipient. "D" for Democratic, "R" for Republican", "I" for Independent, "L" for Libertarian", "3" for other third party and "U" for Unknown. This field will be blank or null for PACs other than leadership PACs.
Text (1)
CRP''',

'''Otherid
Committee id for donor if Type=1* or recipient if Type=2*.
Text (9)
FEC''',

'''RecipCode
A two character code defining the type of recipient. For candidates, the first character is party ("D" for Democratic, "R" for Republican, "3" for Independent, Libertarian or third party, "U" for Unknown.) The second character is "W" for Winner, "L" for Loser, "I" for incumbent, "C" for Challenger, "O" for "Open Seat", and "N" for Non-incumbent. "N" is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is "P." For PACs, the first character is "P" and for outside spending groups, the first character is "O". For both, the second character is "B" for Business, "L" for Labor", "I" for Ideological, "O" for "Other" and "U" for unknown.
Text (2)
CRP''',

'''RecipPrimcode
The industry/ideological code for the recipient - codes beginning with Z1 are candidate committees, codes beginning with Z5 are party committees and codes beginning with J2 are leadership PACs.
Text (5)
CRP''',

'''Amend
Whether the record comes from an amended report
Text (1)
FEC''',

'''Report
The type of report - 1st quarter, year end, etc.
Text (3)
FEC''',

'''PG
Whether the contribution is for a Primary ("P") or General ("G") election.
Text (1)
FEC''',

'''Microfilm
The FEC microfilm record for the contribution
Text (11)
FEC''',

'''Type
The transaction type code for the contribution. 11 is a tribal contribution, 22Z is a contribution refund to a candidate or committee, 24G is a Transfer to an affiliated committee, 24K is a direct contribution, 24R is a election recount disbursement and 24Z is an in kind contribution
Text (3)
FEC''',

'''RealCode
The standard five character code identifying the donor's industry or ideology.Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.
Text (5)
CRP''',

'''Source
Indicates how the Realcode was determined.
Text (5)
CRP'''
]

# %%
# !head -n 10 pac_other18.txt
# Out:
# |2018|,|1010320180036112556|,|C00637983|,|Nardolillo, Bobby|,|ROBERT A NARDOLLILO III|,|GREENE|,|RI|,|02827|,|NARDOLILLO FUNERAL HOME|,|Z1100|,03/03/2017,2000.0,|N00040819|,|R|,|S8RI00110|,|RC|,|Z1100|,|A|,|Q2 |,|P|,|201707200200233820|,|16C|,|Z1100|,|PAC  |
# |2018|,|1010320180036112568|,|C00637983|,|Bobby for Senate|,|LEADERSHIP CONNECTICUT PAC|,|TRUMBULL|,|CT|,|06611|,,|Z1100|,06/26/2017,280.0,|C00499863|,| |,|C00499863|,|PI|,|J1100|,|A|,|Q2 |,|P|,|201707200200233825|,|24G|,|Z1100|,|PAC  |
# |2018|,|1010320180036112716|,|C00443218|,|Wicker Majority Fund|,|WICKER MAJORITY FUND|,|JACKSON|,|MS|,|39205|,,|Z4100|,09/30/2017,3323.0,|N00003280|,|R|,|C00646380|,|RI|,|Z1100|,|A|,|Q3 |,|G|,|201710200200357062|,|18G|,|Z4100|,|PAC  |
# |2018|,|1010320180036112854|,|C00443218|,|2017 Senators Classic Cmte|,|2017 SENATORS CLASSIC COMMITTEE|,|ALEXANDRIA|,|VA|,|22314|,,|Z4100|,09/20/2017,9530.0,|N00003280|,|R|,|C00637181|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357063|,|18G|,|Z4100|,|PAC  |
# |2018|,|1010320180036112855|,|C00443218|,|National Cotton Council|,|COMMITEE FOR ADVANCEMENT OF COTTON|,|MEMPHIS|,|TN|,|38182|,,|A1100|,07/05/2017,2000.0,|N00003280|,|R|,|C00023028|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357063|,|18J|,|A1100|,|PAC  |
# |2018|,|1010320180036112856|,|C00443218|,|Property Casualty Insurers Assn of America|,|PCIPAC|,|CHICAGO|,|IL|,|60631|,,|F3400|,07/05/2017,1000.0,|N00003280|,|R|,|C00066472|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357063|,|18J|,|F3400|,|PAC  |
# |2018|,|1010320180036112857|,|C00443218|,|Liberty Mutual Insurance|,|LIBERTY MUTUAL PAC|,|BOSTON|,|MA|,|02116|,,|F3400|,07/05/2017,1000.0,|N00003280|,|R|,|C00171843|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357064|,|18J|,|F3400|,|PAC  |
# |2018|,|1010320180036112858|,|C00443218|,|Northrop Grumman Innovation Systems|,|ORBITAL ATK INC. PAC|,|ARLINGTON|,|VA|,|22209|,,|D2000|,07/05/2017,1500.0,|N00003280|,|R|,|C00250209|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357064|,|18J|,|D2000|,|PAC  |
# |2018|,|1010320180036112863|,|C00443218|,|Wicker Majority Fund|,|WICKER MAJORITY FUND|,|JACKSON|,|MS|,|39205|,,|Z4100|,09/30/2017,9709.0,|N00003280|,|R|,|C00646380|,|RI|,|Z1100|,|A|,|Q3 |,|P|,|201710200200357066|,|18G|,|Z4100|,|PAC  |
# |2018|,|1010420180036113536|,|C00633073|,|Massachusetts Wisconsin Victory Fund 2018|,|TAMMY BALDWIN FOR SENATE|,|MADISON|,,,,|Z4200|,08/30/2017,326801.0,|N00004367|,|D|,|C00326801|,|DI|,|Z1200|,|A|,|Q3 |,|P|,|201710100200281568|,|24G|,|Z4200|,|PAC  |

# %%
etl_text_file('pac_other18.txt', pac_other18SchemaStr, 'pac_other18', 'crp', column_datetime_formats={'Date': 'MM/dd/yyyy'})
# Out:
# 2018-10-07 19:52:11,489 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 19:52:13,413 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pac_other18;
# INFO  : Compiling command(queryId=hadoop_20181007195218_0aeed2c9-7f81-415c-97bf-f46fd65993e6): DROP TABLE pac_other18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195218_0aeed2c9-7f81-415c-97bf-f46fd65993e6); Time taken: 0.003 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195218_0aeed2c9-7f81-415c-97bf-f46fd65993e6): DROP TABLE pac_other18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195218_0aeed2c9-7f81-415c-97bf-f46fd65993e6); Time taken: 0.007 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE pac_other18
# . . . . . . . . . . . . . > (
#  the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# ifier within a given cycle., orig-datatype Text (19), source FEC',
# =1*., orig-datatype Text (9), source FEC',
#  source CRP',
# source FEC',
#  source FEC',
# , source FEC',
# ), source FEC',
#  employer and/or occupation., orig-datatype Text (38), source FEC',
# ',
# ntribution., orig-datatype Date, source FEC',
#  This will be negative for refunds., orig-datatype Float, source FEC',
# ype Text (9), source CRP',
# ll for PACs other than leadership PACs., orig-datatype Text (1), source CRP',
#  if Type=1* or recipient if Type=2*., orig-datatype Text (9), source FEC',
# urce CRP',
#  leadership PACs., orig-datatype Text (5), source CRP',
#  from an amended report, orig-datatype Text (1), source FEC',
# t quarter, year end, etc., orig-datatype Text (3), source FEC',
# ,
# cord for the contribution, orig-datatype Text (11), source FEC',
# n kind contribution, orig-datatype Text (3), source FEC',
# t (5), source CRP',
# ode was determined., orig-datatype Text (5), source CRP'
# . . . . . . . . . . . . . > )
# 5.008794 from /staging/pac_other18'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/pac_other18';
# INFO  : Compiling command(queryId=hadoop_20181007195218_fdcfbeb9-8888-4203-882f-0e3c5c856d3b): CREATE EXTERNAL TABLE pac_other18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `Filerid` STRING COMMENT 'The committee id number for the PAC making the filing. Refers to donor if Type 2* or recipient if Type=1*., orig-datatype Text (9), source FEC',
# `DonorCmte` STRING COMMENT 'The standardized name for the donor based on the name of the PACs sponsor., orig-datatype Text (50), source CRP',
# `ContribLendTrans` STRING COMMENT 'Reported name of the donor if Type=1* or the recipient if Type=2*., orig-datatype Text (50), source FEC',
# `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address., orig-datatype Text (30), source FEC',
# `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address., orig-datatype Text (2), source FEC',
# `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address., orig-datatype Text (5), source FEC',
# `FECOccEmp` STRING COMMENT 'The donors disclosed employer and/or occupation., orig-datatype Text (38), source FEC',
# `Primcode` STRING COMMENT 'The primary industry/ideological code for the donor PACs sponsor., orig-datatype Text (5), source CRP',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype Date, source FEC',
# `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype Float, source FEC',
# `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number., orig-datatype Text (9), source CRP',
# `Party` STRING COMMENT 'The party (if any) of the recipient. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown. This field will be blank or null for PACs other than leadership PACs., orig-datatype Text (1), source CRP',
# `Otherid` STRING COMMENT 'Committee id for donor if Type=1* or recipient if Type=2*., orig-datatype Text (9), source FEC',
# `RecipCode` STRING COMMENT 'A two character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, the first character is O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `RecipPrimcode` STRING COMMENT 'The industry/ideological code for the recipient - codes beginning with Z1 are candidate committees, codes beginning with Z5 are party committees and codes beginning with J2 are leadership PACs., orig-datatype Text (5), source CRP',
# `Amend` STRING COMMENT 'Whether the record comes from an amended report, orig-datatype Text (1), source FEC',
# `Report` STRING COMMENT 'The type of report - 1st quarter, year end, etc., orig-datatype Text (3), source FEC',
# `PG` STRING COMMENT 'Whether the contribution is for a Primary (P) or General (G) election., orig-datatype Text (1), source FEC',
# `Microfilm` STRING COMMENT 'The FEC microfilm record for the contribution, orig-datatype Text (11), source FEC',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 11 is a tribal contribution, 22Z is a contribution refund to a candidate or committee, 24G is a Transfer to an affiliated committee, 24K is a direct contribution, 24R is a election recount disbursement and 24Z is an in kind contribution, orig-datatype Text (3), source FEC',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology.Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense., orig-datatype Text (5), source CRP',
# `Source` STRING COMMENT 'Indicates how the Realcode was determined., orig-datatype Text (5), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 19:52:15.008794 from /staging/pac_other18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/pac_other18'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195218_fdcfbeb9-8888-4203-882f-0e3c5c856d3b); Time taken: 0.029 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195218_fdcfbeb9-8888-4203-882f-0e3c5c856d3b): CREATE EXTERNAL TABLE pac_other18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `Filerid` STRING COMMENT 'The committee id number for the PAC making the filing. Refers to donor if Type 2* or recipient if Type=1*., orig-datatype Text (9), source FEC',
# `DonorCmte` STRING COMMENT 'The standardized name for the donor based on the name of the PACs sponsor., orig-datatype Text (50), source CRP',
# `ContribLendTrans` STRING COMMENT 'Reported name of the donor if Type=1* or the recipient if Type=2*., orig-datatype Text (50), source FEC',
# `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address., orig-datatype Text (30), source FEC',
# `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address., orig-datatype Text (2), source FEC',
# `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address., orig-datatype Text (5), source FEC',
# `FECOccEmp` STRING COMMENT 'The donors disclosed employer and/or occupation., orig-datatype Text (38), source FEC',
# `Primcode` STRING COMMENT 'The primary industry/ideological code for the donor PACs sponsor., orig-datatype Text (5), source CRP',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype Date, source FEC',
# `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype Float, source FEC',
# `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number., orig-datatype Text (9), source CRP',
# `Party` STRING COMMENT 'The party (if any) of the recipient. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown. This field will be blank or null for PACs other than leadership PACs., orig-datatype Text (1), source CRP',
# `Otherid` STRING COMMENT 'Committee id for donor if Type=1* or recipient if Type=2*., orig-datatype Text (9), source FEC',
# `RecipCode` STRING COMMENT 'A two character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, the first character is O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown., orig-datatype Text (2), source CRP',
# `RecipPrimcode` STRING COMMENT 'The industry/ideological code for the recipient - codes beginning with Z1 are candidate committees, codes beginning with Z5 are party committees and codes beginning with J2 are leadership PACs., orig-datatype Text (5), source CRP',
# `Amend` STRING COMMENT 'Whether the record comes from an amended report, orig-datatype Text (1), source FEC',
# `Report` STRING COMMENT 'The type of report - 1st quarter, year end, etc., orig-datatype Text (3), source FEC',
# `PG` STRING COMMENT 'Whether the contribution is for a Primary (P) or General (G) election., orig-datatype Text (1), source FEC',
# `Microfilm` STRING COMMENT 'The FEC microfilm record for the contribution, orig-datatype Text (11), source FEC',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 11 is a tribal contribution, 22Z is a contribution refund to a candidate or committee, 24G is a Transfer to an affiliated committee, 24K is a direct contribution, 24R is a election recount disbursement and 24Z is an in kind contribution, orig-datatype Text (3), source FEC',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology.Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense., orig-datatype Text (5), source CRP',
# `Source` STRING COMMENT 'Indicates how the Realcode was determined., orig-datatype Text (5), source CRP'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 19:52:15.008794 from /staging/pac_other18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/pac_other18'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195218_fdcfbeb9-8888-4203-882f-0e3c5c856d3b); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.078 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pq_crp_pac_other18;
# INFO  : Compiling command(queryId=hadoop_20181007195222_a356f3ca-59a5-451b-b0e1-8f72dfa56200): DROP TABLE pq_crp_pac_other18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195222_a356f3ca-59a5-451b-b0e1-8f72dfa56200); Time taken: 0.002 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195222_a356f3ca-59a5-451b-b0e1-8f72dfa56200): DROP TABLE pq_crp_pac_other18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195222_a356f3ca-59a5-451b-b0e1-8f72dfa56200); Time taken: 0.006 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.067 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE TABLE pq_crp_pac_other18
# 8.866226 from pac_other18'
# . . . . . . . . . . . . . > STORED AS PARQUET
# . . . . . . . . . . . . . > AS SELECT
# . . . . . . . . . . . . . >     `Cycle` AS `Cycle`,
# . . . . . . . . . . . . . >     `FECRecNo` AS `FECRecNo`,
# . . . . . . . . . . . . . >     `Filerid` AS `Filerid`,
# . . . . . . . . . . . . . >     `DonorCmte` AS `DonorCmte`,
# . . . . . . . . . . . . . >     `ContribLendTrans` AS `ContribLendTrans`,
# . . . . . . . . . . . . . >     `City` AS `City`,
# . . . . . . . . . . . . . >     `State` AS `State`,
# . . . . . . . . . . . . . >     `Zip` AS `Zip`,
# . . . . . . . . . . . . . >     `FECOccEmp` AS `FECOccEmp`,
# . . . . . . . . . . . . . >     `Primcode` AS `Primcode`,
# /dd/yyyy'))) AS `Date`,
# . . . . . . . . . . . . . >     CAST(`Amount` AS DOUBLE) AS `Amount`,
# . . . . . . . . . . . . . >     `RecipID` AS `RecipID`,
# . . . . . . . . . . . . . >     `Party` AS `Party`,
# . . . . . . . . . . . . . >     `Otherid` AS `Otherid`,
# . . . . . . . . . . . . . >     `RecipCode` AS `RecipCode`,
# . . . . . . . . . . . . . >     `RecipPrimcode` AS `RecipPrimcode`,
# . . . . . . . . . . . . . >     `Amend` AS `Amend`,
# . . . . . . . . . . . . . >     `Report` AS `Report`,
# . . . . . . . . . . . . . >     `PG` AS `PG`,
# . . . . . . . . . . . . . >     `Microfilm` AS `Microfilm`,
# . . . . . . . . . . . . . >     `Type` AS `Type`,
# . . . . . . . . . . . . . >     `RealCode` AS `RealCode`,
# . . . . . . . . . . . . . >     `Source` AS `Source`
# . . . . . . . . . . . . . > FROM pac_other18;
# INFO  : Compiling command(queryId=hadoop_20181007195222_6e63f132-ad7c-462e-98ee-31c993216baf): CREATE TABLE pq_crp_pac_other18
# COMMENT 'Auto-generated schema at 2018-10-07 19:52:18.866226 from pac_other18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECRecNo` AS `FECRecNo`,
# `Filerid` AS `Filerid`,
# `DonorCmte` AS `DonorCmte`,
# `ContribLendTrans` AS `ContribLendTrans`,
# `City` AS `City`,
# `State` AS `State`,
# `Zip` AS `Zip`,
# `FECOccEmp` AS `FECOccEmp`,
# `Primcode` AS `Primcode`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# CAST(`Amount` AS DOUBLE) AS `Amount`,
# `RecipID` AS `RecipID`,
# `Party` AS `Party`,
# `Otherid` AS `Otherid`,
# `RecipCode` AS `RecipCode`,
# `RecipPrimcode` AS `RecipPrimcode`,
# `Amend` AS `Amend`,
# `Report` AS `Report`,
# `PG` AS `PG`,
# `Microfilm` AS `Microfilm`,
# `Type` AS `Type`,
# `RealCode` AS `RealCode`,
# `Source` AS `Source`
# FROM pac_other18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:cycle, type:string, comment:null), FieldSchema(name:fecrecno, type:string, comment:null), FieldSchema(name:filerid, type:string, comment:null), FieldSchema(name:donorcmte, type:string, comment:null), FieldSchema(name:contriblendtrans, type:string, comment:null), FieldSchema(name:city, type:string, comment:null), FieldSchema(name:state, type:string, comment:null), FieldSchema(name:zip, type:string, comment:null), FieldSchema(name:fecoccemp, type:string, comment:null), FieldSchema(name:primcode, type:string, comment:null), FieldSchema(name:date, type:date, comment:null), FieldSchema(name:amount, type:double, comment:null), FieldSchema(name:recipid, type:string, comment:null), FieldSchema(name:party, type:string, comment:null), FieldSchema(name:otherid, type:string, comment:null), FieldSchema(name:recipcode, type:string, comment:null), FieldSchema(name:recipprimcode, type:string, comment:null), FieldSchema(name:amend, type:string, comment:null), FieldSchema(name:report, type:string, comment:null), FieldSchema(name:pg, type:string, comment:null), FieldSchema(name:microfilm, type:string, comment:null), FieldSchema(name:type, type:string, comment:null), FieldSchema(name:realcode, type:string, comment:null), FieldSchema(name:source, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195222_6e63f132-ad7c-462e-98ee-31c993216baf); Time taken: 0.169 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195222_6e63f132-ad7c-462e-98ee-31c993216baf): CREATE TABLE pq_crp_pac_other18
# COMMENT 'Auto-generated schema at 2018-10-07 19:52:18.866226 from pac_other18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECRecNo` AS `FECRecNo`,
# `Filerid` AS `Filerid`,
# `DonorCmte` AS `DonorCmte`,
# `ContribLendTrans` AS `ContribLendTrans`,
# `City` AS `City`,
# `State` AS `State`,
# `Zip` AS `Zip`,
# `FECOccEmp` AS `FECOccEmp`,
# `Primcode` AS `Primcode`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# CAST(`Amount` AS DOUBLE) AS `Amount`,
# `RecipID` AS `RecipID`,
# `Party` AS `Party`,
# `Otherid` AS `Otherid`,
# `RecipCode` AS `RecipCode`,
# `RecipPrimcode` AS `RecipPrimcode`,
# `Amend` AS `Amend`,
# `Report` AS `Report`,
# `PG` AS `PG`,
# `Microfilm` AS `Microfilm`,
# `Type` AS `Type`,
# `RealCode` AS `RealCode`,
# `Source` AS `Source`
# FROM pac_other18
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hadoop_20181007195222_6e63f132-ad7c-462e-98ee-31c993216baf
# INFO  : Total jobs = 3
# INFO  : Launching Job 1 out of 3
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1538957855726_0004
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://cap1:8088/proxy/application_1538957855726_0004/
# INFO  : Starting Job = job_1538957855726_0004, Tracking URL = http://cap1:8088/proxy/application_1538957855726_0004/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1538957855726_0004
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# INFO  : 2018-10-07 19:52:30,245 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2018-10-07 19:52:41,502 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 13.06 sec
# INFO  : MapReduce Total cumulative CPU time: 13 seconds 60 msec
# INFO  : Ended Job = job_1538957855726_0004
# INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
# INFO  : Stage-4 is selected by condition resolver.
# INFO  : Stage-3 is filtered out by condition resolver.
# INFO  : Stage-5 is filtered out by condition resolver.
# INFO  : Starting task [Stage-4:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-52-22_405_2069365958758147831-4/-ext-10002 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-52-22_405_2069365958758147831-4/-ext-10004
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/pq_crp_pac_other18 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_19-52-22_405_2069365958758147831-4/-ext-10002
# INFO  : Starting task [Stage-8:DDL] in serial mode
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1   Cumulative CPU: 13.06 sec   HDFS Read: 26629967 HDFS Write: 7252731 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 13 seconds 60 msec
# INFO  : Completed executing command(queryId=hadoop_20181007195222_6e63f132-ad7c-462e-98ee-31c993216baf); Time taken: 20.076 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (20.255 seconds)
# 0: jdbc:hive2://cap1:10000>
# ` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle';
# INFO  : Compiling command(queryId=hadoop_20181007195242_30c451d8-b300-41d2-a878-256f83d0bae2): ALTER TABLE pq_crp_pac_other18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195242_30c451d8-b300-41d2-a878-256f83d0bae2); Time taken: 0.021 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195242_30c451d8-b300-41d2-a878-256f83d0bae2): ALTER TABLE pq_crp_pac_other18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195242_30c451d8-b300-41d2-a878-256f83d0bae2); Time taken: 0.035 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.065 seconds)
# CRecNo` STRING COMMENT 'A unique record identifier within a given cycle.';
# INFO  : Compiling command(queryId=hadoop_20181007195242_d23b1892-570e-483d-b13c-004064fbb295): ALTER TABLE pq_crp_pac_other18 CHANGE `FECRecNo` `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195242_d23b1892-570e-483d-b13c-004064fbb295); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195242_d23b1892-570e-483d-b13c-004064fbb295): ALTER TABLE pq_crp_pac_other18 CHANGE `FECRecNo` `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195242_d23b1892-570e-483d-b13c-004064fbb295); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# ers to donor if Type 2* or recipient if Type=1*.';
# INFO  : Compiling command(queryId=hadoop_20181007195242_600ab99f-c6d5-484f-a971-a88407a1a71b): ALTER TABLE pq_crp_pac_other18 CHANGE `Filerid` `Filerid` STRING COMMENT 'The committee id number for the PAC making the filing. Refers to donor if Type 2* or recipient if Type=1*.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195242_600ab99f-c6d5-484f-a971-a88407a1a71b); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195242_600ab99f-c6d5-484f-a971-a88407a1a71b): ALTER TABLE pq_crp_pac_other18 CHANGE `Filerid` `Filerid` STRING COMMENT 'The committee id number for the PAC making the filing. Refers to donor if Type 2* or recipient if Type=1*.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195242_600ab99f-c6d5-484f-a971-a88407a1a71b); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.058 seconds)
# of the PACs sponsor.';
# INFO  : Compiling command(queryId=hadoop_20181007195242_c025ac9a-7c52-44ae-8100-fc3d4708b930): ALTER TABLE pq_crp_pac_other18 CHANGE `DonorCmte` `DonorCmte` STRING COMMENT 'The standardized name for the donor based on the name of the PACs sponsor.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195242_c025ac9a-7c52-44ae-8100-fc3d4708b930); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195242_c025ac9a-7c52-44ae-8100-fc3d4708b930): ALTER TABLE pq_crp_pac_other18 CHANGE `DonorCmte` `DonorCmte` STRING COMMENT 'The standardized name for the donor based on the name of the PACs sponsor.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195242_c025ac9a-7c52-44ae-8100-fc3d4708b930); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
#  the recipient if Type=2*.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_4261e097-4a36-4d76-950f-c952e53e3fee): ALTER TABLE pq_crp_pac_other18 CHANGE `ContribLendTrans` `ContribLendTrans` STRING COMMENT 'Reported name of the donor if Type=1* or the recipient if Type=2*.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_4261e097-4a36-4d76-950f-c952e53e3fee); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_4261e097-4a36-4d76-950f-c952e53e3fee): ALTER TABLE pq_crp_pac_other18 CHANGE `ContribLendTrans` `ContribLendTrans` STRING COMMENT 'Reported name of the donor if Type=1* or the recipient if Type=2*.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_4261e097-4a36-4d76-950f-c952e53e3fee); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.058 seconds)
# loyers address.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_4e8267ff-b3ed-4726-aa5d-83d43413959b): ALTER TABLE pq_crp_pac_other18 CHANGE `City` `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_4e8267ff-b3ed-4726-aa5d-83d43413959b); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_4e8267ff-b3ed-4726-aa5d-83d43413959b): ALTER TABLE pq_crp_pac_other18 CHANGE `City` `City` STRING COMMENT 'The donors city. This could be based on a home address or an employers address.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_4e8267ff-b3ed-4726-aa5d-83d43413959b); Time taken: 0.034 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# employers address.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_8ef90cc4-5ed0-483a-aa79-95580c503620): ALTER TABLE pq_crp_pac_other18 CHANGE `State` `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_8ef90cc4-5ed0-483a-aa79-95580c503620); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_8ef90cc4-5ed0-483a-aa79-95580c503620): ALTER TABLE pq_crp_pac_other18 CHANGE `State` `State` STRING COMMENT 'The donors state. This could be based on a home address or an employers address.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_8ef90cc4-5ed0-483a-aa79-95580c503620); Time taken: 0.043 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.067 seconds)
# mployers address.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_770b4b1c-6603-425f-ac28-c60b1ba89268): ALTER TABLE pq_crp_pac_other18 CHANGE `Zip` `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_770b4b1c-6603-425f-ac28-c60b1ba89268); Time taken: 0.018 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_770b4b1c-6603-425f-ac28-c60b1ba89268): ALTER TABLE pq_crp_pac_other18 CHANGE `Zip` `Zip` STRING COMMENT 'The donors zip code. This could be based on a home address or an employers address.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_770b4b1c-6603-425f-ac28-c60b1ba89268); Time taken: 0.038 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.065 seconds)
# ECOccEmp` STRING COMMENT 'The donors disclosed employer and/or occupation.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_a1270c4d-3b2b-403c-b864-4d570e48b87e): ALTER TABLE pq_crp_pac_other18 CHANGE `FECOccEmp` `FECOccEmp` STRING COMMENT 'The donors disclosed employer and/or occupation.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_a1270c4d-3b2b-403c-b864-4d570e48b87e); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_a1270c4d-3b2b-403c-b864-4d570e48b87e): ALTER TABLE pq_crp_pac_other18 CHANGE `FECOccEmp` `FECOccEmp` STRING COMMENT 'The donors disclosed employer and/or occupation.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_a1270c4d-3b2b-403c-b864-4d570e48b87e); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.056 seconds)
#  sponsor.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_22145325-e69a-4ddf-b64e-0000e4c7c3ad): ALTER TABLE pq_crp_pac_other18 CHANGE `Primcode` `Primcode` STRING COMMENT 'The primary industry/ideological code for the donor PACs sponsor.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_22145325-e69a-4ddf-b64e-0000e4c7c3ad); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_22145325-e69a-4ddf-b64e-0000e4c7c3ad): ALTER TABLE pq_crp_pac_other18 CHANGE `Primcode` `Primcode` STRING COMMENT 'The primary industry/ideological code for the donor PACs sponsor.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_22145325-e69a-4ddf-b64e-0000e4c7c3ad); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.056 seconds)
# DATE COMMENT 'The reported date of the contribution.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_5525ad5b-10b8-403c-b867-36f15025ce83): ALTER TABLE pq_crp_pac_other18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_5525ad5b-10b8-403c-b867-36f15025ce83); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_5525ad5b-10b8-403c-b867-36f15025ce83): ALTER TABLE pq_crp_pac_other18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_5525ad5b-10b8-403c-b867-36f15025ce83); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# nt` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_e46e3b36-b5ba-4cb9-a165-d1a8f3ff94dc): ALTER TABLE pq_crp_pac_other18 CHANGE `Amount` `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_e46e3b36-b5ba-4cb9-a165-d1a8f3ff94dc); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_e46e3b36-b5ba-4cb9-a165-d1a8f3ff94dc): ALTER TABLE pq_crp_pac_other18 CHANGE `Amount` `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_e46e3b36-b5ba-4cb9-a165-d1a8f3ff94dc); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.056 seconds)
#  be the FEC committee id number.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_483e5d27-15f5-4243-a3cb-455bddb0cdce): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipID` `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_483e5d27-15f5-4243-a3cb-455bddb0cdce); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_483e5d27-15f5-4243-a3cb-455bddb0cdce): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipID` `RecipID` STRING COMMENT 'The recipients id number. If the contribution is to a candidate this will be the candidates unique candidate id number. Otherwise, it will be the FEC committee id number.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_483e5d27-15f5-4243-a3cb-455bddb0cdce); Time taken: 0.035 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.057 seconds)
# .';
# INFO  : Compiling command(queryId=hadoop_20181007195243_1d22d05b-8135-4eab-b276-17e76de8fae2): ALTER TABLE pq_crp_pac_other18 CHANGE `Party` `Party` STRING COMMENT 'The party (if any) of the recipient. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown. This field will be blank or null for PACs other than leadership PACs.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_1d22d05b-8135-4eab-b276-17e76de8fae2); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_1d22d05b-8135-4eab-b276-17e76de8fae2): ALTER TABLE pq_crp_pac_other18 CHANGE `Party` `Party` STRING COMMENT 'The party (if any) of the recipient. D for Democratic, R for Republican, I for Independent, L for Libertarian, 3 for other third party and U for Unknown. This field will be blank or null for PACs other than leadership PACs.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_1d22d05b-8135-4eab-b276-17e76de8fae2); Time taken: 0.041 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.066 seconds)
# ';
# INFO  : Compiling command(queryId=hadoop_20181007195243_c01e6cf5-9219-4df2-870a-ffe8e461c77f): ALTER TABLE pq_crp_pac_other18 CHANGE `Otherid` `Otherid` STRING COMMENT 'Committee id for donor if Type=1* or recipient if Type=2*.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_c01e6cf5-9219-4df2-870a-ffe8e461c77f); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_c01e6cf5-9219-4df2-870a-ffe8e461c77f): ALTER TABLE pq_crp_pac_other18 CHANGE `Otherid` `Otherid` STRING COMMENT 'Committee id for donor if Type=1* or recipient if Type=2*.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_c01e6cf5-9219-4df2-870a-ffe8e461c77f); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.059 seconds)
# and U for unknown.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_66834216-07bc-4d34-9d5c-625275c769e9): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, the first character is O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_66834216-07bc-4d34-9d5c-625275c769e9); Time taken: 0.016 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_66834216-07bc-4d34-9d5c-625275c769e9): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipCode` `RecipCode` STRING COMMENT 'A two character code defining the type of recipient. For candidates, the first character is party (D for Democratic, R for Republican, 3 for Independent, Libertarian or third party, U for Unknown.) The second character is W for Winner, L for Loser, I for incumbent, C for Challenger, O for Open Seat, and N for Non-incumbent. N is reserved for candidates that are neither in office nor running during the cycle in question. For party committees, the first character is party and the second character is P. For PACs, the first character is P and for outside spending groups, the first character is O. For both, the second character is B for Business, L for Labor, I for Ideological, O for Other and U for unknown.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_66834216-07bc-4d34-9d5c-625275c769e9); Time taken: 0.031 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.055 seconds)
# e party committees and codes beginning with J2 are leadership PACs.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_5bae29db-5ac3-4498-8ac3-ba8ad85081c4): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipPrimcode` `RecipPrimcode` STRING COMMENT 'The industry/ideological code for the recipient - codes beginning with Z1 are candidate committees, codes beginning with Z5 are party committees and codes beginning with J2 are leadership PACs.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_5bae29db-5ac3-4498-8ac3-ba8ad85081c4); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_5bae29db-5ac3-4498-8ac3-ba8ad85081c4): ALTER TABLE pq_crp_pac_other18 CHANGE `RecipPrimcode` `RecipPrimcode` STRING COMMENT 'The industry/ideological code for the recipient - codes beginning with Z1 are candidate committees, codes beginning with Z5 are party committees and codes beginning with J2 are leadership PACs.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_5bae29db-5ac3-4498-8ac3-ba8ad85081c4); Time taken: 0.03 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.052 seconds)
# ` STRING COMMENT 'Whether the record comes from an amended report';
# INFO  : Compiling command(queryId=hadoop_20181007195243_6fde46e8-9cf1-4742-b907-74651c7a7e78): ALTER TABLE pq_crp_pac_other18 CHANGE `Amend` `Amend` STRING COMMENT 'Whether the record comes from an amended report'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_6fde46e8-9cf1-4742-b907-74651c7a7e78); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_6fde46e8-9cf1-4742-b907-74651c7a7e78): ALTER TABLE pq_crp_pac_other18 CHANGE `Amend` `Amend` STRING COMMENT 'Whether the record comes from an amended report'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_6fde46e8-9cf1-4742-b907-74651c7a7e78); Time taken: 0.033 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.052 seconds)
# rt` STRING COMMENT 'The type of report - 1st quarter, year end, etc.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_5a2277d4-c63c-4138-b363-be92e28aaf00): ALTER TABLE pq_crp_pac_other18 CHANGE `Report` `Report` STRING COMMENT 'The type of report - 1st quarter, year end, etc.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_5a2277d4-c63c-4138-b363-be92e28aaf00); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_5a2277d4-c63c-4138-b363-be92e28aaf00): ALTER TABLE pq_crp_pac_other18 CHANGE `Report` `Report` STRING COMMENT 'The type of report - 1st quarter, year end, etc.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_5a2277d4-c63c-4138-b363-be92e28aaf00); Time taken: 0.031 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.053 seconds)
# n.';
# INFO  : Compiling command(queryId=hadoop_20181007195243_da8c7849-615d-4e04-ae36-9dfa823d22cd): ALTER TABLE pq_crp_pac_other18 CHANGE `PG` `PG` STRING COMMENT 'Whether the contribution is for a Primary (P) or General (G) election.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195243_da8c7849-615d-4e04-ae36-9dfa823d22cd); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195243_da8c7849-615d-4e04-ae36-9dfa823d22cd): ALTER TABLE pq_crp_pac_other18 CHANGE `PG` `PG` STRING COMMENT 'Whether the contribution is for a Primary (P) or General (G) election.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195243_da8c7849-615d-4e04-ae36-9dfa823d22cd); Time taken: 0.031 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.054 seconds)
# icrofilm` STRING COMMENT 'The FEC microfilm record for the contribution';
# INFO  : Compiling command(queryId=hadoop_20181007195244_c96f3c5c-3e44-4c5a-b99d-1d77f1dc310d): ALTER TABLE pq_crp_pac_other18 CHANGE `Microfilm` `Microfilm` STRING COMMENT 'The FEC microfilm record for the contribution'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195244_c96f3c5c-3e44-4c5a-b99d-1d77f1dc310d); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195244_c96f3c5c-3e44-4c5a-b99d-1d77f1dc310d): ALTER TABLE pq_crp_pac_other18 CHANGE `Microfilm` `Microfilm` STRING COMMENT 'The FEC microfilm record for the contribution'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195244_c96f3c5c-3e44-4c5a-b99d-1d77f1dc310d); Time taken: 0.042 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.064 seconds)
# tion recount disbursement and 24Z is an in kind contribution';
# INFO  : Compiling command(queryId=hadoop_20181007195244_d302b897-a081-43df-9ce9-d758a7dbb2c5): ALTER TABLE pq_crp_pac_other18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 11 is a tribal contribution, 22Z is a contribution refund to a candidate or committee, 24G is a Transfer to an affiliated committee, 24K is a direct contribution, 24R is a election recount disbursement and 24Z is an in kind contribution'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195244_d302b897-a081-43df-9ce9-d758a7dbb2c5); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195244_d302b897-a081-43df-9ce9-d758a7dbb2c5): ALTER TABLE pq_crp_pac_other18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 11 is a tribal contribution, 22Z is a contribution refund to a candidate or committee, 24G is a Transfer to an affiliated committee, 24K is a direct contribution, 24R is a election recount disbursement and 24Z is an in kind contribution'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195244_d302b897-a081-43df-9ce9-d758a7dbb2c5); Time taken: 0.03 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.052 seconds)
# a realcode of Air Defense.';
# INFO  : Compiling command(queryId=hadoop_20181007195244_5d796fd4-5eb0-4c3e-bed1-bbfa9ad5cdf4): ALTER TABLE pq_crp_pac_other18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology.Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195244_5d796fd4-5eb0-4c3e-bed1-bbfa9ad5cdf4); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195244_5d796fd4-5eb0-4c3e-bed1-bbfa9ad5cdf4): ALTER TABLE pq_crp_pac_other18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology.Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195244_5d796fd4-5eb0-4c3e-bed1-bbfa9ad5cdf4); Time taken: 0.032 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.054 seconds)
# ce` STRING COMMENT 'Indicates how the Realcode was determined.';
# INFO  : Compiling command(queryId=hadoop_20181007195244_7df3d194-12b8-420d-9cd0-926a8d4bafe0): ALTER TABLE pq_crp_pac_other18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the Realcode was determined.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007195244_7df3d194-12b8-420d-9cd0-926a8d4bafe0); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007195244_7df3d194-12b8-420d-9cd0-926a8d4bafe0): ALTER TABLE pq_crp_pac_other18 CHANGE `Source` `Source` STRING COMMENT 'Indicates how the Realcode was determined.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007195244_7df3d194-12b8-420d-9cd0-926a8d4bafe0); Time taken: 0.03 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.052 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# 2018-10-07 19:52:45,156 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/pac_other18
# done

# %%
sc.sql('SELECT * FROM pq_crp_pac_other18').limit(10).show()
# Out:
# +-----+-------------------+---------+--------------------+--------------------+----------+-----+-----+--------------------+--------+----------+--------+---------+-----+---------+---------+-------------+-----+------+---+------------------+----+--------+------+
# |cycle|           fecrecno|  filerid|           donorcmte|    contriblendtrans|      city|state|  zip|           fecoccemp|primcode|      date|  amount|  recipid|party|  otherid|recipcode|recipprimcode|amend|report| pg|         microfilm|type|realcode|source|
# +-----+-------------------+---------+--------------------+--------------------+----------+-----+-----+--------------------+--------+----------+--------+---------+-----+---------+---------+-------------+-----+------+---+------------------+----+--------+------+
# | 2018|1010320180036112556|C00637983|   Nardolillo, Bobby|ROBERT A NARDOLLI...|    GREENE|   RI|02827|NARDOLILLO FUNERA...|   Z1100|2017-03-03|  2000.0|N00040819|    R|S8RI00110|       RC|        Z1100|    A|   Q2 |  P|201707200200233820| 16C|   Z1100| PAC  |
# | 2018|1010320180036112568|C00637983|    Bobby for Senate|LEADERSHIP CONNEC...|  TRUMBULL|   CT|06611|                    |   Z1100|2017-06-26|   280.0|C00499863|     |C00499863|       PI|        J1100|    A|   Q2 |  P|201707200200233825| 24G|   Z1100| PAC  |
# | 2018|1010320180036112716|C00443218|Wicker Majority Fund|WICKER MAJORITY FUND|   JACKSON|   MS|39205|                    |   Z4100|2017-09-30|  3323.0|N00003280|    R|C00646380|       RI|        Z1100|    A|   Q3 |  G|201710200200357062| 18G|   Z4100| PAC  |
# | 2018|1010320180036112854|C00443218|2017 Senators Cla...|2017 SENATORS CLA...|ALEXANDRIA|   VA|22314|                    |   Z4100|2017-09-20|  9530.0|N00003280|    R|C00637181|       RI|        Z1100|    A|   Q3 |  P|201710200200357063| 18G|   Z4100| PAC  |
# | 2018|1010320180036112855|C00443218|National Cotton C...|COMMITEE FOR ADVA...|   MEMPHIS|   TN|38182|                    |   A1100|2017-07-05|  2000.0|N00003280|    R|C00023028|       RI|        Z1100|    A|   Q3 |  P|201710200200357063| 18J|   A1100| PAC  |
# | 2018|1010320180036112856|C00443218|Property Casualty...|              PCIPAC|   CHICAGO|   IL|60631|                    |   F3400|2017-07-05|  1000.0|N00003280|    R|C00066472|       RI|        Z1100|    A|   Q3 |  P|201710200200357063| 18J|   F3400| PAC  |
# | 2018|1010320180036112857|C00443218|Liberty Mutual In...|  LIBERTY MUTUAL PAC|    BOSTON|   MA|02116|                    |   F3400|2017-07-05|  1000.0|N00003280|    R|C00171843|       RI|        Z1100|    A|   Q3 |  P|201710200200357064| 18J|   F3400| PAC  |
# | 2018|1010320180036112858|C00443218|Northrop Grumman ...|ORBITAL ATK INC. PAC| ARLINGTON|   VA|22209|                    |   D2000|2017-07-05|  1500.0|N00003280|    R|C00250209|       RI|        Z1100|    A|   Q3 |  P|201710200200357064| 18J|   D2000| PAC  |
# | 2018|1010320180036112863|C00443218|Wicker Majority Fund|WICKER MAJORITY FUND|   JACKSON|   MS|39205|                    |   Z4100|2017-09-30|  9709.0|N00003280|    R|C00646380|       RI|        Z1100|    A|   Q3 |  P|201710200200357066| 18G|   Z4100| PAC  |
# | 2018|1010420180036113536|C00633073|Massachusetts Wis...|TAMMY BALDWIN FOR...|   MADISON|     |     |                    |   Z4200|2017-08-30|326801.0|N00004367|    D|C00326801|       DI|        Z1200|    A|   Q3 |  P|201710100200281568| 24G|   Z4200| PAC  |
# +-----+-------------------+---------+--------------------+--------------------+----------+-----+-----+--------------------+--------+----------+--------+---------+-----+---------+---------+-------------+-----+------+---+------------------+----+--------+------+

# %%
sc.sql('DESCRIBE TABLE pq_crp_pac_other18').show()
# Out:
# +----------------+---------+--------------------+
# |        col_name|data_type|             comment|
# +----------------+---------+--------------------+
# |           cycle|   string|Last year (even y...|
# |        fecrecno|   string|A unique record i...|
# |         filerid|   string|The committee id ...|
# |       donorcmte|   string|The standardized ...|
# |contriblendtrans|   string|Reported name of ...|
# |            city|   string|The donors city. ...|
# |           state|   string|The donors state....|
# |             zip|   string|The donors zip co...|
# |       fecoccemp|   string|The donors disclo...|
# |        primcode|   string|The primary indus...|
# |            date|     date|The reported date...|
# |          amount|   double|The amount contri...|
# |         recipid|   string|The recipients id...|
# |           party|   string|The party (if any...|
# |         otherid|   string|Committee id for ...|
# |       recipcode|   string|A two character c...|
# |   recipprimcode|   string|The industry/ideo...|
# |           amend|   string|Whether the recor...|
# |          report|   string|The type of repor...|
# |              pg|   string|Whether the contr...|
# +----------------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# # `pacs18`

# %% [markdown]
# `pacs18` schema string: https://www.opensecrets.org/resources/datadictionary/Data%20Dictionary%20for%20PAC%20to%20Cands%20Data.htm

# %%
pacs18SchemaStr = [
'''Cycle
Last year (even year) of the federal 2-year election cycle
Text (4)
FEC''',

'''FECRecNo
A unique record identifier within a given cycle.
Text (19)
FEC''',

'''PACID
The committee id number for the PAC making the contribution.
Text (9)
FEC''',

'''CID
A unique identifier for candidates that is constant throughout cycles.
Text (9)
CRP''',

'''Amount
The amount contributed. This will be negative for refunds.
float
FEC''',

'''Date
The reported date of the contribution.
Date
FEC''',

'''RealCode
The standard five character code identifying the donor's industry or ideology. Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.
Text (5)
CRP''',

'''Type
The transaction type code for the contribution. 24A is an Independent Expenditure against the candidate, 24C is a coordinated expenditure, 24E is an independent expenditure for the candidate, 24F is a communication cost for the candidate, 24K is a direct contribution, 24N is a communication cost against the candidate and 24Z is an in kind contribution
Text (3)
FEC''',

'''DI
Whether the contribution is direct ("D") or indirect ("I."). Indirect contributions include independent expenditures and communications costs, are not subject to contribution limits and must be made completely independently of the candidate. Indirect contributions can also be against the candidate.
Text (1)
CRP''',

'''FECCandID
FECCandID of recipient candidate
Text (9)
FEC'''
]

# %%
# !head -n 10 pacs18.txt
# Out:
# |2018|,|4031520181518958016|,|C00150797|,|N00035527|,1000,02/06/2018,|K1200|,|24K|,|D|,|H4AR04048|
# |2018|,|4021520181504727622|,|C00343459|,|N00028152|,5000,12/27/2017,|H1130|,|24K|,|D|,|H6CA22125|
# |2018|,|4062120181570992000|,|C00005249|,|N00035509|,3000,05/18/2018,|F3300|,|24K|,|D|,|H4IA03115|
# |2018|,|4121120171484669562|,|C00449165|,|N00003689|,1000,11/08/2017,|M3100|,|24K|,|D|,|H8OH01043|
# |2018|,|4101220171458221652|,|C00171843|,|N00002408|,5000,09/21/2017,|F3400|,|24K|,|D|,|H2SC02042|
# |2018|,|4051820181565917536|,|C00035675|,|N00031933|,1000,04/23/2018,|H4300|,|24K|,|D|,|H0MA10082|
# |2018|,|4072420171429498467|,|C00035451|,|N00034584|,2000,06/27/2017,|LT100|,|24K|,|D|,|S2ME00158|
# |2018|,|4112020171465723593|,|C00033779|,|N00035346|,1000,10/24/2017,|F4100|,|24K|,|D|,|H4GA01039|
# |2018|,|4042720181530493912|,|C00502906|,|N00033518|,1500,03/22/2018,|C6200|,|24K|,|D|,|H2GA09150|
# |2018|,|4022220181514504696|,|C00542431|,|N00003105|,5000,01/08/2018,|J1100|,|24K|,|D|,|S8TN00337|

# %%
etl_text_file('pacs18.txt', pacs18SchemaStr, 'pacs18', 'crp', column_datetime_formats={'Date': 'MM/dd/yyyy'})
# Out:
# 2018-10-07 20:09:30,942 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2018-10-07 20:09:32,857 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pacs18;
# INFO  : Compiling command(queryId=hadoop_20181007200938_d4f5ba35-9b33-4b45-9a57-9dd84697aa5e): DROP TABLE pacs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007200938_d4f5ba35-9b33-4b45-9a57-9dd84697aa5e); Time taken: 0.002 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007200938_d4f5ba35-9b33-4b45-9a57-9dd84697aa5e): DROP TABLE pacs18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007200938_d4f5ba35-9b33-4b45-9a57-9dd84697aa5e); Time taken: 0.006 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.063 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE EXTERNAL TABLE pacs18
# . . . . . . . . . . . . . > (
#  the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# ifier within a given cycle., orig-datatype Text (19), source FEC',
# for the PAC making the contribution., orig-datatype Text (9), source FEC',
# ',
#  This will be negative for refunds., orig-datatype float, source FEC',
# ntribution., orig-datatype Date, source FEC',
# xt (5), source CRP',
# ribution, orig-datatype Text (3), source FEC',
# so be against the candidate., orig-datatype Text (1), source CRP',
# nt candidate, orig-datatype Text (9), source FEC'
# . . . . . . . . . . . . . > )
# 4.713670 from /staging/pacs18'
# CSVSerde'
# . . . . . . . . . . . . . > WITH SERDEPROPERTIES (
# . . . . . . . . . . . . . >    "separatorChar" = ",",
# . . . . . . . . . . . . . >    "quoteChar"     = "|"
# . . . . . . . . . . . . . > )
# . . . . . . . . . . . . . > STORED AS TEXTFILE
# . . . . . . . . . . . . . > LOCATION '/staging/pacs18';
# INFO  : Compiling command(queryId=hadoop_20181007200938_ee8c3354-31e0-4c46-aa4e-386d09d99a87): CREATE EXTERNAL TABLE pacs18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `PACID` STRING COMMENT 'The committee id number for the PAC making the contribution., orig-datatype Text (9), source FEC',
# `CID` STRING COMMENT 'A unique identifier for candidates that is constant throughout cycles., orig-datatype Text (9), source CRP',
# `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype float, source FEC',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype Date, source FEC',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense., orig-datatype Text (5), source CRP',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 24A is an Independent Expenditure against the candidate, 24C is a coordinated expenditure, 24E is an independent expenditure for the candidate, 24F is a communication cost for the candidate, 24K is a direct contribution, 24N is a communication cost against the candidate and 24Z is an in kind contribution, orig-datatype Text (3), source FEC',
# `DI` STRING COMMENT 'Whether the contribution is direct (D) or indirect (I.). Indirect contributions include independent expenditures and communications costs, are not subject to contribution limits and must be made completely independently of the candidate. Indirect contributions can also be against the candidate., orig-datatype Text (1), source CRP',
# `FECCandID` STRING COMMENT 'FECCandID of recipient candidate, orig-datatype Text (9), source FEC'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 20:09:34.713670 from /staging/pacs18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/pacs18'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007200938_ee8c3354-31e0-4c46-aa4e-386d09d99a87); Time taken: 0.006 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007200938_ee8c3354-31e0-4c46-aa4e-386d09d99a87): CREATE EXTERNAL TABLE pacs18
# (
# `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle, orig-datatype Text (4), source FEC',
# `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle., orig-datatype Text (19), source FEC',
# `PACID` STRING COMMENT 'The committee id number for the PAC making the contribution., orig-datatype Text (9), source FEC',
# `CID` STRING COMMENT 'A unique identifier for candidates that is constant throughout cycles., orig-datatype Text (9), source CRP',
# `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds., orig-datatype float, source FEC',
# `Date` DATE COMMENT 'The reported date of the contribution., orig-datatype Date, source FEC',
# `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense., orig-datatype Text (5), source CRP',
# `Type` STRING COMMENT 'The transaction type code for the contribution. 24A is an Independent Expenditure against the candidate, 24C is a coordinated expenditure, 24E is an independent expenditure for the candidate, 24F is a communication cost for the candidate, 24K is a direct contribution, 24N is a communication cost against the candidate and 24Z is an in kind contribution, orig-datatype Text (3), source FEC',
# `DI` STRING COMMENT 'Whether the contribution is direct (D) or indirect (I.). Indirect contributions include independent expenditures and communications costs, are not subject to contribution limits and must be made completely independently of the candidate. Indirect contributions can also be against the candidate., orig-datatype Text (1), source CRP',
# `FECCandID` STRING COMMENT 'FECCandID of recipient candidate, orig-datatype Text (9), source FEC'
# )
# COMMENT 'Auto-generated schema at 2018-10-07 20:09:34.713670 from /staging/pacs18'
# ROW FORMAT SERDE 'org.apache.hadoop.hive.serde2.OpenCSVSerde'
# WITH SERDEPROPERTIES (
# "separatorChar" = ",",
# "quoteChar"     = "|"
# )
# STORED AS TEXTFILE
# LOCATION '/staging/pacs18'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007200938_ee8c3354-31e0-4c46-aa4e-386d09d99a87); Time taken: 0.022 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.037 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/opt/hadoop/share/hadoop/common/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Connecting to jdbc:hive2://cap1:10000
# Connected to: Apache Hive (version 3.1.0)
# Driver: Hive JDBC (version 3.1.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> DROP TABLE pq_crp_pacs18;
# INFO  : Compiling command(queryId=hadoop_20181007200941_58820585-b8c3-4f40-aa7e-60ca2456102f): DROP TABLE pq_crp_pacs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007200941_58820585-b8c3-4f40-aa7e-60ca2456102f); Time taken: 0.008 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007200941_58820585-b8c3-4f40-aa7e-60ca2456102f): DROP TABLE pq_crp_pacs18
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007200941_58820585-b8c3-4f40-aa7e-60ca2456102f); Time taken: 0.049 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.114 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> CREATE TABLE pq_crp_pacs18
# 8.536919 from pacs18'
# . . . . . . . . . . . . . > STORED AS PARQUET
# . . . . . . . . . . . . . > AS SELECT
# . . . . . . . . . . . . . >     `Cycle` AS `Cycle`,
# . . . . . . . . . . . . . >     `FECRecNo` AS `FECRecNo`,
# . . . . . . . . . . . . . >     `PACID` AS `PACID`,
# . . . . . . . . . . . . . >     `CID` AS `CID`,
# . . . . . . . . . . . . . >     CAST(`Amount` AS DOUBLE) AS `Amount`,
# /dd/yyyy'))) AS `Date`,
# . . . . . . . . . . . . . >     `RealCode` AS `RealCode`,
# . . . . . . . . . . . . . >     `Type` AS `Type`,
# . . . . . . . . . . . . . >     `DI` AS `DI`,
# . . . . . . . . . . . . . >     `FECCandID` AS `FECCandID`
# . . . . . . . . . . . . . > FROM pacs18;
# INFO  : Compiling command(queryId=hadoop_20181007200942_f3e4f687-9303-4c37-80e1-e267509ebbe7): CREATE TABLE pq_crp_pacs18
# COMMENT 'Auto-generated schema at 2018-10-07 20:09:38.536919 from pacs18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECRecNo` AS `FECRecNo`,
# `PACID` AS `PACID`,
# `CID` AS `CID`,
# CAST(`Amount` AS DOUBLE) AS `Amount`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# `RealCode` AS `RealCode`,
# `Type` AS `Type`,
# `DI` AS `DI`,
# `FECCandID` AS `FECCandID`
# FROM pacs18
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:cycle, type:string, comment:null), FieldSchema(name:fecrecno, type:string, comment:null), FieldSchema(name:pacid, type:string, comment:null), FieldSchema(name:cid, type:string, comment:null), FieldSchema(name:amount, type:double, comment:null), FieldSchema(name:date, type:date, comment:null), FieldSchema(name:realcode, type:string, comment:null), FieldSchema(name:type, type:string, comment:null), FieldSchema(name:di, type:string, comment:null), FieldSchema(name:feccandid, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007200942_f3e4f687-9303-4c37-80e1-e267509ebbe7); Time taken: 0.135 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007200942_f3e4f687-9303-4c37-80e1-e267509ebbe7): CREATE TABLE pq_crp_pacs18
# COMMENT 'Auto-generated schema at 2018-10-07 20:09:38.536919 from pacs18'
# STORED AS PARQUET
# AS SELECT
# `Cycle` AS `Cycle`,
# `FECRecNo` AS `FECRecNo`,
# `PACID` AS `PACID`,
# `CID` AS `CID`,
# CAST(`Amount` AS DOUBLE) AS `Amount`,
# TO_DATE(FROM_UNIXTIME(UNIX_TIMESTAMP(`Date`, 'MM/dd/yyyy'))) AS `Date`,
# `RealCode` AS `RealCode`,
# `Type` AS `Type`,
# `DI` AS `DI`,
# `FECCandID` AS `FECCandID`
# FROM pacs18
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = hadoop_20181007200942_f3e4f687-9303-4c37-80e1-e267509ebbe7
# INFO  : Total jobs = 3
# INFO  : Launching Job 1 out of 3
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1538957855726_0006
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://cap1:8088/proxy/application_1538957855726_0006/
# INFO  : Starting Job = job_1538957855726_0006, Tracking URL = http://cap1:8088/proxy/application_1538957855726_0006/
# INFO  : Kill Command = /opt/hadoop/bin/mapred job  -kill job_1538957855726_0006
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# INFO  : 2018-10-07 20:09:48,859 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2018-10-07 20:10:00,203 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 12.26 sec
# INFO  : MapReduce Total cumulative CPU time: 12 seconds 260 msec
# INFO  : Ended Job = job_1538957855726_0006
# INFO  : Starting task [Stage-7:CONDITIONAL] in serial mode
# INFO  : Stage-4 is selected by condition resolver.
# INFO  : Stage-3 is filtered out by condition resolver.
# INFO  : Stage-5 is filtered out by condition resolver.
# INFO  : Starting task [Stage-4:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_20-09-42_124_87362740771010135-4/-ext-10002 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_20-09-42_124_87362740771010135-4/-ext-10004
# INFO  : Starting task [Stage-0:MOVE] in serial mode
# INFO  : Moving data to directory hdfs://cap1/user/hive/warehouse/pq_crp_pacs18 from hdfs://cap1/user/hive/warehouse/.hive-staging_hive_2018-10-07_20-09-42_124_87362740771010135-4/-ext-10002
# INFO  : Starting task [Stage-8:DDL] in serial mode
# INFO  : Starting task [Stage-2:STATS] in serial mode
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1   Cumulative CPU: 12.26 sec   HDFS Read: 19097575 HDFS Write: 6085393 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 12 seconds 260 msec
# INFO  : Completed executing command(queryId=hadoop_20181007200942_f3e4f687-9303-4c37-80e1-e267509ebbe7); Time taken: 20.149 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (20.292 seconds)
# 0: jdbc:hive2://cap1:10000>
# ING COMMENT 'Last year (even year) of the federal 2-year election cycle';
# INFO  : Compiling command(queryId=hadoop_20181007201002_a87cd650-83e3-4645-b103-448cb7b9f831): ALTER TABLE pq_crp_pacs18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_a87cd650-83e3-4645-b103-448cb7b9f831); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_a87cd650-83e3-4645-b103-448cb7b9f831): ALTER TABLE pq_crp_pacs18 CHANGE `Cycle` `Cycle` STRING COMMENT 'Last year (even year) of the federal 2-year election cycle'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_a87cd650-83e3-4645-b103-448cb7b9f831); Time taken: 0.026 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.049 seconds)
# o` STRING COMMENT 'A unique record identifier within a given cycle.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_7550ddb1-0e63-42bd-a884-88b616785ac7): ALTER TABLE pq_crp_pacs18 CHANGE `FECRecNo` `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_7550ddb1-0e63-42bd-a884-88b616785ac7); Time taken: 0.013 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_7550ddb1-0e63-42bd-a884-88b616785ac7): ALTER TABLE pq_crp_pacs18 CHANGE `FECRecNo` `FECRecNo` STRING COMMENT 'A unique record identifier within a given cycle.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_7550ddb1-0e63-42bd-a884-88b616785ac7); Time taken: 0.026 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.046 seconds)
# ING COMMENT 'The committee id number for the PAC making the contribution.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_a6b7a011-46ad-4572-a618-9126657e8f3d): ALTER TABLE pq_crp_pacs18 CHANGE `PACID` `PACID` STRING COMMENT 'The committee id number for the PAC making the contribution.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_a6b7a011-46ad-4572-a618-9126657e8f3d); Time taken: 0.012 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_a6b7a011-46ad-4572-a618-9126657e8f3d): ALTER TABLE pq_crp_pacs18 CHANGE `PACID` `PACID` STRING COMMENT 'The committee id number for the PAC making the contribution.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_a6b7a011-46ad-4572-a618-9126657e8f3d); Time taken: 0.027 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.047 seconds)
# ;
# INFO  : Compiling command(queryId=hadoop_20181007201002_5d832aa0-bc3b-420e-afd3-6dd51149fa3b): ALTER TABLE pq_crp_pacs18 CHANGE `CID` `CID` STRING COMMENT 'A unique identifier for candidates that is constant throughout cycles.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_5d832aa0-bc3b-420e-afd3-6dd51149fa3b); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_5d832aa0-bc3b-420e-afd3-6dd51149fa3b): ALTER TABLE pq_crp_pacs18 CHANGE `CID` `CID` STRING COMMENT 'A unique identifier for candidates that is constant throughout cycles.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_5d832aa0-bc3b-420e-afd3-6dd51149fa3b); Time taken: 0.027 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.048 seconds)
# OUBLE COMMENT 'The amount contributed. This will be negative for refunds.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_8ce93098-cc58-4739-9b23-8c806fa20aee): ALTER TABLE pq_crp_pacs18 CHANGE `Amount` `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_8ce93098-cc58-4739-9b23-8c806fa20aee); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_8ce93098-cc58-4739-9b23-8c806fa20aee): ALTER TABLE pq_crp_pacs18 CHANGE `Amount` `Amount` DOUBLE COMMENT 'The amount contributed. This will be negative for refunds.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_8ce93098-cc58-4739-9b23-8c806fa20aee); Time taken: 0.03 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.057 seconds)
# COMMENT 'The reported date of the contribution.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_160c9f33-8f5f-4b95-bea3-b3e6c1e0d4a3): ALTER TABLE pq_crp_pacs18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_160c9f33-8f5f-4b95-bea3-b3e6c1e0d4a3); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_160c9f33-8f5f-4b95-bea3-b3e6c1e0d4a3): ALTER TABLE pq_crp_pacs18 CHANGE `Date` `Date` DATE COMMENT 'The reported date of the contribution.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_160c9f33-8f5f-4b95-bea3-b3e6c1e0d4a3); Time taken: 0.026 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.048 seconds)
# alcode of Air Defense.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_59478399-e889-441b-b217-fca17a9ef295): ALTER TABLE pq_crp_pacs18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_59478399-e889-441b-b217-fca17a9ef295); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_59478399-e889-441b-b217-fca17a9ef295): ALTER TABLE pq_crp_pacs18 CHANGE `RealCode` `RealCode` STRING COMMENT 'The standard five character code identifying the donors industry or ideology. Usually based on Primcode. Sometimes a PAC sponsor will have secondary interests which may replace the main realcode depending on recipient. For example, Boeing is primarily Air Transport but has Air Defense interests. Thus Boeing contributions to members of the Armed Services committee would have a realcode of Air Defense.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_59478399-e889-441b-b217-fca17a9ef295); Time taken: 0.029 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.053 seconds)
# candidate and 24Z is an in kind contribution';
# INFO  : Compiling command(queryId=hadoop_20181007201002_e9f84044-ce0b-44fd-a25c-ea04c4fe11ab): ALTER TABLE pq_crp_pacs18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 24A is an Independent Expenditure against the candidate, 24C is a coordinated expenditure, 24E is an independent expenditure for the candidate, 24F is a communication cost for the candidate, 24K is a direct contribution, 24N is a communication cost against the candidate and 24Z is an in kind contribution'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_e9f84044-ce0b-44fd-a25c-ea04c4fe11ab); Time taken: 0.024 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_e9f84044-ce0b-44fd-a25c-ea04c4fe11ab): ALTER TABLE pq_crp_pacs18 CHANGE `Type` `Type` STRING COMMENT 'The transaction type code for the contribution. 24A is an Independent Expenditure against the candidate, 24C is a coordinated expenditure, 24E is an independent expenditure for the candidate, 24F is a communication cost for the candidate, 24K is a direct contribution, 24N is a communication cost against the candidate and 24Z is an in kind contribution'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_e9f84044-ce0b-44fd-a25c-ea04c4fe11ab); Time taken: 0.036 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.067 seconds)
# ate. Indirect contributions can also be against the candidate.';
# INFO  : Compiling command(queryId=hadoop_20181007201002_c0aecfd1-8053-4bbf-9468-4456d69bc297): ALTER TABLE pq_crp_pacs18 CHANGE `DI` `DI` STRING COMMENT 'Whether the contribution is direct (D) or indirect (I.). Indirect contributions include independent expenditures and communications costs, are not subject to contribution limits and must be made completely independently of the candidate. Indirect contributions can also be against the candidate.'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_c0aecfd1-8053-4bbf-9468-4456d69bc297); Time taken: 0.015 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_c0aecfd1-8053-4bbf-9468-4456d69bc297): ALTER TABLE pq_crp_pacs18 CHANGE `DI` `DI` STRING COMMENT 'Whether the contribution is direct (D) or indirect (I.). Indirect contributions include independent expenditures and communications costs, are not subject to contribution limits and must be made completely independently of the candidate. Indirect contributions can also be against the candidate.'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_c0aecfd1-8053-4bbf-9468-4456d69bc297); Time taken: 0.026 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.048 seconds)
# dID` STRING COMMENT 'FECCandID of recipient candidate';
# INFO  : Compiling command(queryId=hadoop_20181007201002_b03eda72-0dcc-4e3d-8fa7-05744e21aa8c): ALTER TABLE pq_crp_pacs18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'FECCandID of recipient candidate'
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=hadoop_20181007201002_b03eda72-0dcc-4e3d-8fa7-05744e21aa8c); Time taken: 0.014 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hadoop_20181007201002_b03eda72-0dcc-4e3d-8fa7-05744e21aa8c): ALTER TABLE pq_crp_pacs18 CHANGE `FECCandID` `FECCandID` STRING COMMENT 'FECCandID of recipient candidate'
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=hadoop_20181007201002_b03eda72-0dcc-4e3d-8fa7-05744e21aa8c); Time taken: 0.028 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.049 seconds)
# 0: jdbc:hive2://cap1:10000>
# 0: jdbc:hive2://cap1:10000> Closing: 0: jdbc:hive2://cap1:10000
# 2018-10-07 20:10:03,920 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Deleted /staging/pacs18
# done

# %%
sc.sql('SELECT * FROM pq_crp_pacs18').limit(10).show()
# Out:
# +-----+-------------------+---------+---------+------+----------+--------+----+---+---------+
# |cycle|           fecrecno|    pacid|      cid|amount|      date|realcode|type| di|feccandid|
# +-----+-------------------+---------+---------+------+----------+--------+----+---+---------+
# | 2018|4031520181518958016|C00150797|N00035527|1000.0|2018-02-06|   K1200| 24K|  D|H4AR04048|
# | 2018|4021520181504727622|C00343459|N00028152|5000.0|2017-12-27|   H1130| 24K|  D|H6CA22125|
# | 2018|4062120181570992000|C00005249|N00035509|3000.0|2018-05-18|   F3300| 24K|  D|H4IA03115|
# | 2018|4121120171484669562|C00449165|N00003689|1000.0|2017-11-08|   M3100| 24K|  D|H8OH01043|
# | 2018|4101220171458221652|C00171843|N00002408|5000.0|2017-09-21|   F3400| 24K|  D|H2SC02042|
# | 2018|4051820181565917536|C00035675|N00031933|1000.0|2018-04-23|   H4300| 24K|  D|H0MA10082|
# | 2018|4072420171429498467|C00035451|N00034584|2000.0|2017-06-27|   LT100| 24K|  D|S2ME00158|
# | 2018|4112020171465723593|C00033779|N00035346|1000.0|2017-10-24|   F4100| 24K|  D|H4GA01039|
# | 2018|4042720181530493912|C00502906|N00033518|1500.0|2018-03-22|   C6200| 24K|  D|H2GA09150|
# | 2018|4022220181514504696|C00542431|N00003105|5000.0|2018-01-08|   J1100| 24K|  D|S8TN00337|
# +-----+-------------------+---------+---------+------+----------+--------+----+---+---------+

# %%
sc.sql('DESCRIBE TABLE pq_crp_pacs18').show()
# Out:
# +---------+---------+--------------------+
# | col_name|data_type|             comment|
# +---------+---------+--------------------+
# |    cycle|   string|Last year (even y...|
# | fecrecno|   string|A unique record i...|
# |    pacid|   string|The committee id ...|
# |      cid|   string|A unique identifi...|
# |   amount|   double|The amount contri...|
# |     date|     date|The reported date...|
# | realcode|   string|The standard five...|
# |     type|   string|The transaction t...|
# |       di|   string|Whether the contr...|
# |feccandid|   string|FECCandID of reci...|
# +---------+---------+--------------------+
